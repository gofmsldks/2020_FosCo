# %% [markdown]
# # 파이썬 PATH 초기화

# %%
# !echo $PYTHONPATH
# %env PYTHONPATH=
# Out:
# /env/python
# env: PYTHONPATH=

# %% [markdown]
# # 아나콘다 설치 및 SYSTEMPATH 적용

# %%
# !wget -c https://repo.continuum.io/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# !chmod +x Anaconda3-5.1.0-Linux-x86_64.sh
# !bash ./Anaconda3-5.1.0-Linux-x86_64.sh -b -f -p /usr/local 
# !conda install -q -y --prefix /usr/local python=3.6 ujson
# Out:
# --2020-11-12 03:43:26--  https://repo.continuum.io/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/archive/Anaconda3-5.1.0-Linux-x86_64.sh [following]
# --2020-11-12 03:43:26--  https://repo.anaconda.com/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 577996269 (551M) [application/x-sh]
# Saving to: ‘Anaconda3-5.1.0-Linux-x86_64.sh’
#
# Anaconda3-5.1.0-Lin 100%[===================>] 551.22M   155MB/s    in 3.6s
#
# 2020-11-12 03:43:30 (153 MB/s) - ‘Anaconda3-5.1.0-Linux-x86_64.sh’ saved [577996269/577996269]
#
# PREFIX=/usr/local
# installing: python-3.6.4-hc3d631a_1 ...
# Python 3.6.4 :: Anaconda, Inc.
# installing: ca-certificates-2017.08.26-h1d4fec5_0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: intel-openmp-2018.0.0-hc7b2577_8 ...
# installing: libgcc-ng-7.2.0-h7cc24e2_2 ...
# installing: libgfortran-ng-7.2.0-h9f7466a_2 ...
# installing: libstdcxx-ng-7.2.0-h7a57d05_2 ...
# installing: bzip2-1.0.6-h9a117a8_4 ...
# installing: expat-2.2.5-he0dffb1_0 ...
# installing: gmp-6.1.2-h6c8ec71_1 ...
# installing: graphite2-1.3.10-hf63cedd_1 ...
# installing: icu-58.2-h9c2bf20_1 ...
# installing: jbig-2.1-hdba287a_0 ...
# installing: jpeg-9b-h024ee3a_2 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: libsodium-1.0.15-hf101ebd_0 ...
# installing: libtool-2.4.6-h544aabb_3 ...
# installing: libxcb-1.12-hcd93eb1_4 ...
# installing: lzo-2.10-h49e0be7_2 ...
# installing: mkl-2018.0.1-h19d6760_4 ...
# installing: ncurses-6.0-h9df7e31_2 ...
# installing: openssl-1.0.2n-hb7f436b_0 ...
# installing: patchelf-0.9-hf79760b_2 ...
# installing: pcre-8.41-hc27e229_1 ...
# installing: pixman-0.34.0-hceecf20_3 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: unixodbc-2.3.4-hc36303a_1 ...
# installing: xz-5.2.3-h55aa19d_2 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: glib-2.53.6-h5d9569c_2 ...
# installing: hdf5-1.10.1-h9caa474_1 ...
# installing: libedit-3.1-heed3624_0 ...
# installing: libpng-1.6.34-hb9fc6fc_0 ...
# installing: libssh2-1.8.0-h9cfc8f7_4 ...
# installing: libtiff-4.0.9-h28f6b97_0 ...
# installing: libxml2-2.9.7-h26e45fe_0 ...
# installing: mpfr-3.1.5-h11a74b3_2 ...
# installing: pandoc-1.19.2.1-hea2e7c5_1 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: zeromq-4.2.2-hbedb6e5_2 ...
# installing: dbus-1.12.2-hc3f9b76_1 ...
# installing: freetype-2.8-hab7d2ae_1 ...
# installing: gstreamer-1.12.4-hb53b477_0 ...
# installing: libcurl-7.58.0-h1ad7b7a_0 ...
# installing: libxslt-1.1.32-h1312cb7_0 ...
# installing: mpc-1.0.3-hec55b23_5 ...
# installing: sqlite-3.22.0-h1bed415_0 ...
# installing: curl-7.58.0-h84994c4_0 ...
# installing: fontconfig-2.12.4-h88586e7_1 ...
# installing: gst-plugins-base-1.12.4-h33fb286_0 ...
# installing: alabaster-0.7.10-py36h306e16b_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: attrs-17.4.0-py36_0 ...
# installing: backports-1.0-py36hfa02d7e_1 ...
# installing: beautifulsoup4-4.6.0-py36h49b8c8c_1 ...
# installing: bitarray-0.8.1-py36h14c3975_1 ...
# installing: boto-2.48.0-py36h6e4cd66_1 ...
# installing: cairo-1.14.12-h77bcde2_0 ...
# installing: certifi-2018.1.18-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: click-6.7-py36h5253387_0 ...
# installing: cloudpickle-0.5.2-py36_1 ...
# installing: colorama-0.3.9-py36h489cec4_0 ...
# installing: contextlib2-0.5.5-py36h6c84a62_0 ...
# installing: dask-core-0.16.1-py36_0 ...
# installing: decorator-4.2.1-py36_0 ...
# installing: docutils-0.14-py36hb0f60f5_0 ...
# installing: entrypoints-0.2.3-py36h1aec115_2 ...
# installing: et_xmlfile-1.0.1-py36hd6bccc3_0 ...
# installing: fastcache-1.0.2-py36h14c3975_2 ...
# installing: filelock-2.0.13-py36h646ffb5_0 ...
# installing: glob2-0.6-py36he249c77_0 ...
# installing: gmpy2-2.0.8-py36hc8893dd_2 ...
# installing: greenlet-0.4.12-py36h2d503a6_0 ...
# installing: heapdict-1.0.0-py36_2 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: imagesize-0.7.1-py36h52d8127_0 ...
# installing: ipython_genutils-0.2.0-py36hb52b0d5_0 ...
# installing: itsdangerous-0.24-py36h93cc618_1 ...
# installing: jdcal-1.3-py36h4c697fb_0 ...
# installing: lazy-object-proxy-1.3.1-py36h10fcdad_0 ...
# installing: llvmlite-0.21.0-py36ha241eea_0 ...
# installing: locket-0.2.0-py36h787c0ad_1 ...
# installing: lxml-4.1.1-py36hf71bdeb_1 ...
# installing: markupsafe-1.0-py36hd9260cd_1 ...
# installing: mccabe-0.6.1-py36h5ad9710_1 ...
# installing: mistune-0.8.3-py36_0 ...
# installing: mkl-service-1.1.2-py36h17a0993_4 ...
# installing: mpmath-1.0.0-py36hfeacd6b_2 ...
# installing: msgpack-python-0.5.1-py36h6bb024c_0 ...
# installing: multipledispatch-0.4.9-py36h41da3fb_0 ...
# installing: numpy-1.14.0-py36h3dfced4_1 ...
# installing: olefile-0.45.1-py36_0 ...
# installing: pandocfilters-1.4.2-py36ha6701b7_1 ...
# installing: parso-0.1.1-py36h35f843b_0 ...
# installing: path.py-10.5-py36h55ceabb_0 ...
# installing: pep8-1.7.1-py36_0 ...
# installing: pickleshare-0.7.4-py36h63277f8_0 ...
# installing: pkginfo-1.4.1-py36h215d178_1 ...
# installing: pluggy-0.6.0-py36hb689045_0 ...
# installing: ply-3.10-py36hed35086_0 ...
# installing: psutil-5.4.3-py36h14c3975_0 ...
# installing: ptyprocess-0.5.2-py36h69acd42_0 ...
# installing: py-1.5.2-py36h29bf505_0 ...
# installing: pycodestyle-2.3.1-py36hf609f19_0 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pycrypto-2.6.1-py36h14c3975_7 ...
# installing: pycurl-7.43.0.1-py36hb7f436b_0 ...
# installing: pyodbc-4.0.22-py36hf484d3e_0 ...
# installing: pyparsing-2.2.0-py36hee85983_1 ...
# installing: pysocks-1.6.7-py36hd97a5b1_1 ...
# installing: pytz-2017.3-py36h63b9c63_0 ...
# installing: pyyaml-3.12-py36hafb9ca4_1 ...
# installing: pyzmq-16.0.3-py36he2533c7_0 ...
# installing: qt-5.6.2-h974d657_12 ...
# installing: qtpy-1.3.1-py36h3691cc8_0 ...
# installing: rope-0.10.7-py36h147e2ec_0 ...
# installing: ruamel_yaml-0.15.35-py36h14c3975_1 ...
# installing: send2trash-1.4.2-py36_0 ...
# installing: simplegeneric-0.8.1-py36_2 ...
# installing: sip-4.18.1-py36h51ed4ed_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: snowballstemmer-1.2.1-py36h6febd40_0 ...
# installing: sortedcontainers-1.5.9-py36_0 ...
# installing: sphinxcontrib-1.0-py36h6d0f590_1 ...
# installing: sqlalchemy-1.2.1-py36h14c3975_0 ...
# installing: tblib-1.3.2-py36h34cf8b6_0 ...
# installing: testpath-0.3.1-py36h8cadb63_0 ...
# installing: toolz-0.9.0-py36_0 ...
# installing: tornado-4.5.3-py36_0 ...
# installing: typing-3.6.2-py36h7da032a_0 ...
# installing: unicodecsv-0.14.1-py36ha668878_0 ...
# installing: wcwidth-0.1.7-py36hdf4376a_0 ...
# installing: webencodings-0.5.1-py36h800622e_1 ...
# installing: werkzeug-0.14.1-py36_0 ...
# installing: wrapt-1.10.11-py36h28b7045_0 ...
# installing: xlrd-1.1.0-py36h1db9f0c_1 ...
# installing: xlsxwriter-1.0.2-py36h3de1aca_0 ...
# installing: xlwt-1.3.0-py36h7b00a1f_0 ...
# installing: babel-2.5.3-py36_0 ...
# installing: backports.shutil_get_terminal_size-1.0.0-py36hfea85ff_2 ...
# installing: bottleneck-1.2.1-py36haac1ea0_0 ...
# installing: cffi-1.11.4-py36h9745a5d_0 ...
# installing: conda-verify-2.0.0-py36h98955d8_0 ...
# installing: cycler-0.10.0-py36h93f1223_0 ...
# installing: cytoolz-0.9.0-py36h14c3975_0 ...
# installing: h5py-2.7.1-py36h3585f63_0 ...
# installing: harfbuzz-1.7.4-hc5b324e_0 ...
# installing: html5lib-1.0.1-py36h2f9c1c0_0 ...
# installing: jedi-0.11.1-py36_0 ...
# installing: networkx-2.1-py36_0 ...
# installing: nltk-3.2.5-py36h7532b22_0 ...
# installing: numba-0.36.2-np114py36hc6662d5_0 ...
# installing: numexpr-2.6.4-py36hc4a3f9a_0 ...
# installing: openpyxl-2.4.10-py36_0 ...
# installing: packaging-16.8-py36ha668100_1 ...
# installing: partd-0.3.8-py36h36fd896_0 ...
# installing: pathlib2-2.3.0-py36h49efa8e_0 ...
# installing: pexpect-4.3.1-py36_0 ...
# installing: pillow-5.0.0-py36h3deb7b8_0 ...
# installing: pyqt-5.6.0-py36h0386399_5 ...
# installing: python-dateutil-2.6.1-py36h88d3b88_1 ...
# installing: pywavelets-0.5.2-py36he602eb0_0 ...
# installing: qtawesome-0.4.4-py36h609ed8c_0 ...
# installing: scipy-1.0.0-py36hbf646e7_0 ...
# installing: setuptools-38.4.0-py36_0 ...
# installing: singledispatch-3.4.0.3-py36h7a266c3_0 ...
# installing: sortedcollections-0.5.3-py36h3c761f9_0 ...
# installing: sphinxcontrib-websupport-1.0.1-py36hb5cb234_1 ...
# installing: sympy-1.1.1-py36hc6d1c1c_0 ...
# installing: terminado-0.8.1-py36_1 ...
# installing: traitlets-4.3.2-py36h674d592_0 ...
# installing: zict-0.1.3-py36h3a3bf81_0 ...
# installing: astroid-1.6.1-py36_0 ...
# installing: bleach-2.1.2-py36_0 ...
# installing: clyent-1.2.2-py36h7e57e65_1 ...
# installing: cryptography-2.1.4-py36hd09be54_0 ...
# installing: cython-0.27.3-py36h1860423_0 ...
# installing: datashape-0.5.4-py36h3ad6b5c_0 ...
# installing: distributed-1.20.2-py36_0 ...
# installing: get_terminal_size-1.0.0-haa9412d_0 ...
# installing: gevent-1.2.2-py36h2fe25dc_0 ...
# installing: imageio-2.2.0-py36he555465_0 ...
# installing: isort-4.2.15-py36had401c0_0 ...
# installing: jinja2-2.10-py36ha16c418_0 ...
# installing: jsonschema-2.6.0-py36h006f8b5_0 ...
# installing: jupyter_core-4.4.0-py36h7c827e3_0 ...
# installing: matplotlib-2.1.2-py36h0e671d2_0 ...
# installing: navigator-updater-0.1.0-py36h14770f7_0 ...
# installing: nose-1.3.7-py36hcdf7029_2 ...
# installing: pandas-0.22.0-py36hf484d3e_0 ...
# installing: pango-1.41.0-hd475d92_0 ...
# installing: patsy-0.5.0-py36_0 ...
# installing: pyflakes-1.6.0-py36h7bd6a15_0 ...
# installing: pygments-2.2.0-py36h0d3125c_0 ...
# installing: pytables-3.4.2-py36h3b5282a_2 ...
# installing: pytest-3.3.2-py36_0 ...
# installing: scikit-learn-0.19.1-py36h7aa7ec6_0 ...
# installing: wheel-0.30.0-py36hfd4bba0_1 ...
# installing: astropy-2.0.3-py36h14c3975_0 ...
# installing: bkcharts-0.2-py36h735825a_0 ...
# installing: bokeh-0.12.13-py36h2f9c1c0_0 ...
# installing: flask-0.12.2-py36hb24657c_0 ...
# installing: jupyter_client-5.2.2-py36_0 ...
# installing: nbformat-4.4.0-py36h31c9010_0 ...
# installing: pip-9.0.1-py36h6c6f9ce_4 ...
# installing: prompt_toolkit-1.0.15-py36h17d85b1_0 ...
# installing: pylint-1.8.2-py36_0 ...
# installing: pyopenssl-17.5.0-py36h20ba746_0 ...
# installing: statsmodels-0.8.0-py36h8533d0b_0 ...
# installing: dask-0.16.1-py36_0 ...
# installing: flask-cors-3.0.3-py36h2d857d3_0 ...
# installing: ipython-6.2.1-py36h88c514a_1 ...
# installing: nbconvert-5.3.1-py36hb41ffb7_0 ...
# installing: seaborn-0.8.1-py36hfad7ec4_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: ipykernel-4.8.0-py36_0 ...
# installing: odo-0.5.1-py36h90ed295_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: scikit-image-0.13.1-py36h14c3975_1 ...
# installing: anaconda-client-1.6.9-py36_0 ...
# installing: blaze-0.11.3-py36h4e06776_0 ...
# installing: jupyter_console-5.2.0-py36he59e554_1 ...
# installing: notebook-5.4.0-py36_0 ...
# installing: qtconsole-4.3.1-py36h8f73b5b_0 ...
# installing: sphinx-1.6.6-py36_0 ...
# installing: anaconda-project-0.8.2-py36h44fb852_0 ...
# installing: jupyterlab_launcher-0.10.2-py36_0 ...
# installing: numpydoc-0.7.0-py36h18f165f_0 ...
# installing: widgetsnbextension-3.1.0-py36_0 ...
# installing: anaconda-navigator-1.7.0-py36_0 ...
# installing: ipywidgets-7.1.1-py36_0 ...
# installing: jupyterlab-0.31.5-py36_0 ...
# installing: spyder-3.2.6-py36_0 ...
# installing: _ipyw_jlab_nb_ext_conf-0.1.0-py36he11e457_0 ...
# installing: jupyter-1.0.0-py36_4 ...
# installing: anaconda-5.1.0-py36_2 ...
# installing: conda-4.4.10-py36_0 ...
# installing: conda-build-3.4.1-py36_0 ...
# installation finished.
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - python=3.6
#     - ujson
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     tk-8.6.10                  |       hbc83047_0         3.2 MB
#     setuptools-50.3.1          |   py36h06a4308_1         900 KB
#     python-3.6.12              |       hcff3b4d_2        34.0 MB
#     certifi-2020.6.20          |     pyhd3eb1b0_3         159 KB
#     ca-certificates-2020.10.14 |                0         128 KB
#     wheel-0.35.1               |             py_0          36 KB
#     ujson-4.0.1                |   py36he6710b0_0          48 KB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     zlib-1.2.11                |       h7b6447c_3         120 KB
#     libedit-3.1.20191231       |       h14c3975_1         121 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         645 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     readline-8.0               |       h7b6447c_0         428 KB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     pip-20.2.4                 |   py36h06a4308_0         2.1 MB
#     sqlite-3.33.0              |       h62c20be_0         2.0 MB
#     openssl-1.1.1h             |       h7b6447c_0         3.8 MB
#     ------------------------------------------------------------
#                                            Total:        61.4 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:    0.1-main
#     ld_impl_linux-64: 2.33.1-h53a641e_7
#     ujson:            4.0.1-py36he6710b0_0
#
# The following packages will be UPDATED:
#
#     ca-certificates:  2017.08.26-h1d4fec5_0 --> 2020.10.14-0
#     certifi:          2018.1.18-py36_0      --> 2020.6.20-pyhd3eb1b0_3
#     libedit:          3.1-heed3624_0        --> 3.1.20191231-h14c3975_1
#     libffi:           3.2.1-hd88cf55_4      --> 3.3-he6710b0_2
#     libgcc-ng:        7.2.0-h7cc24e2_2      --> 9.1.0-hdf63c60_0
#     libstdcxx-ng:     7.2.0-h7a57d05_2      --> 9.1.0-hdf63c60_0
#     ncurses:          6.0-h9df7e31_2        --> 6.2-he6710b0_1
#     openssl:          1.0.2n-hb7f436b_0     --> 1.1.1h-h7b6447c_0
#     pip:              9.0.1-py36h6c6f9ce_4  --> 20.2.4-py36h06a4308_0
#     python:           3.6.4-hc3d631a_1      --> 3.6.12-hcff3b4d_2
#     readline:         7.0-ha6073c6_4        --> 8.0-h7b6447c_0
#     setuptools:       38.4.0-py36_0         --> 50.3.1-py36h06a4308_1
#     sqlite:           3.22.0-h1bed415_0     --> 3.33.0-h62c20be_0
#     tk:               8.6.7-hc745277_3      --> 8.6.10-hbc83047_0
#     wheel:            0.30.0-py36hfd4bba0_1 --> 0.35.1-py_0
#     xz:               5.2.3-h55aa19d_2      --> 5.2.5-h7b6447c_0
#     zlib:             1.2.11-ha838bed_2     --> 1.2.11-h7b6447c_3
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import sys
sys.path.insert(0, "/usr/local/lib/python3.6/site-packages/")
sys.path

import ujson
print(ujson.dumps({1:2}))
# Out:
# {"1":2}

# %%
# !python -V
# !which python
# !ls -al /usr/bin/python
# Out:
# Python 3.6.12 :: Anaconda, Inc.
# /usr/local/bin/python
# lrwxrwxrwx 1 root root 9 Apr 16  2018 /usr/bin/python -> python2.7

# %%
# !apt-get install libpcl-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   avahi-daemon bind9-host cython default-libmysqlclient-dev geoclue-2.0
#   geoip-database gstreamer1.0-plugins-base iio-sensor-proxy javascript-common
#   libarmadillo-dev libarpack2-dev libavahi-core7 libavahi-glib1 libbind9-160
#   libblas-dev libblas3 libbrotli1 libcap2-bin libcdparanoia0 libdaemon0
#   libdap-dev libdapserver7v5 libdns1100 libeigen3-dev libepsilon-dev
#   libflann-dev libflann1.9 libfreexl-dev libfyba-dev libgdal-dev
#   libgeoclue-2-0 libgeoip1 libgeos-dev libgeotiff-dev libgif-dev
#   libgl1-mesa-glx libgl2ps-dev libgstreamer-plugins-base1.0-0
#   libgstreamer1.0-0 libhdf4-alt-dev libhdf5-mpi-dev libhdf5-openmpi-dev
#   libhyphen0 libisc169 libisccc160 libisccfg160 libjs-jquery libjs-sphinxdoc
#   libjs-underscore libjson-c-dev libjsoncpp-dev libkml-dev libkmlconvenience1
#   libkmlregionator1 libkmlxsd1 liblwres160 libmbim-glib4 libmbim-proxy
#   libminizip-dev libmm-glib0 libmysqlclient-dev libnetcdf-cxx-legacy-dev
#   libnetcdf-dev libnl-genl-3-200 libnss-mdns libogdi3.2-dev libopenjp2-7-dev
#   libopenni-dev libopenni-sensor-pointclouds0 libopenni0 libopenni2-0
#   libopenni2-dev liborc-0.4-0 libpam-cap libpcl-apps1.8 libpcl-common1.8
#   libpcl-features1.8 libpcl-filters1.8 libpcl-io1.8 libpcl-kdtree1.8
#   libpcl-keypoints1.8 libpcl-ml1.8 libpcl-octree1.8 libpcl-outofcore1.8
#   libpcl-people1.8 libpcl-recognition1.8 libpcl-registration1.8
#   libpcl-sample-consensus1.8 libpcl-search1.8 libpcl-segmentation1.8
#   libpcl-stereo1.8 libpcl-surface1.8 libpcl-tracking1.8
#   libpcl-visualization1.8 libpoppler-dev libpoppler-private-dev libpq-dev
#   libproj-dev libqhull-dev libqhull-r7 libqmi-glib5 libqmi-proxy
#   libqt5designer5 libqt5designercomponents5 libqt5help5 libqt5opengl5
#   libqt5opengl5-dev libqt5positioning5 libqt5qml5 libqt5quick5
#   libqt5quickparticles5 libqt5quicktest5 libqt5quickwidgets5 libqt5sensors5
#   libqt5sql5-sqlite libqt5webchannel5 libqt5webkit5 libqt5webkit5-dev
#   libspatialite-dev libsqlite3-dev libsuperlu-dev libtheora-dev
#   libtinyxml2.6.2v5 liburiparser-dev libvisual-0.4-0 libvtk6-dev libvtk6-java
#   libvtk6-jni libvtk6-qt-dev libvtk6.3-qt libwebp-dev libwoff1 libxerces-c-dev
#   modemmanager openni-utils python-asn1crypto python-attr python-autobahn
#   python-automat python-cbor python-cffi-backend python-click python-colorama
#   python-concurrent.futures python-constantly python-cryptography
#   python-enum34 python-hyperlink python-idna python-incremental
#   python-ipaddress python-lz4 python-mpi4py python-nacl python-olefile
#   python-openssl python-pam python-pil python-pkg-resources python-pyasn1
#   python-pyasn1-modules python-qrcode python-serial python-service-identity
#   python-six python-snappy python-trie python-trollius python-twisted
#   python-twisted-bin python-twisted-core python-txaio python-u-msgpack
#   python-ubjson python-vtk6 python-wsaccel python-zope.interface qt5-assistant
#   qt5-qmltooling-plugins qtdeclarative5-dev qttools5-dev qttools5-dev-tools
#   qttools5-private-dev tcl-vtk6 unixodbc-dev usb-modeswitch
#   usb-modeswitch-data vtk6 wpasupplicant
# Suggested packages:
#   avahi-autoipd cython-doc gvfs apache2 | lighttpd | httpd libitpp-dev
#   liblapack-doc libeigen3-doc libmrpt-dev libgdal-doc geoip-bin
#   libgeotiff-epsg libvisual-0.4-plugins gstreamer1.0-tools libhdf5-doc
#   netcdf-bin netcdf-doc avahi-autoipd | zeroconf openni-doc openni2-doc
#   libpcl-doc postgresql-doc-10 proj-bin sqlite3-doc libsuperlu-doc vtk6-doc
#   vtk6-examples java-virtual-machine libxerces-c-doc python-attr-doc
#   python-cryptography-doc python-cryptography-vectors python-enum34-doc
#   python-nacl-doc python-openssl-doc python-openssl-dbg python-pam-dbg
#   python-pil-doc python-pil-dbg python-setuptools python-wxgtk3.0
#   | python-wxgtk python-trie-doc python-twisted-bin-dbg python-gtk2
#   python-glade2 python-qt3 python-wxgtk3.0 python-txaio-doc mayavi2 qt5-doc
#   comgt wvdial wpagui libengine-pkcs11-openssl
# The following NEW packages will be installed:
#   avahi-daemon bind9-host cython default-libmysqlclient-dev geoclue-2.0
#   geoip-database gstreamer1.0-plugins-base iio-sensor-proxy javascript-common
#   libarmadillo-dev libarpack2-dev libavahi-core7 libavahi-glib1 libbind9-160
#   libblas-dev libblas3 libbrotli1 libcap2-bin libcdparanoia0 libdaemon0
#   libdap-dev libdapserver7v5 libdns1100 libeigen3-dev libepsilon-dev
#   libflann-dev libflann1.9 libfreexl-dev libfyba-dev libgdal-dev
#   libgeoclue-2-0 libgeoip1 libgeos-dev libgeotiff-dev libgif-dev
#   libgl1-mesa-glx libgl2ps-dev libgstreamer-plugins-base1.0-0
#   libgstreamer1.0-0 libhdf4-alt-dev libhdf5-mpi-dev libhdf5-openmpi-dev
#   libhyphen0 libisc169 libisccc160 libisccfg160 libjs-jquery libjs-sphinxdoc
#   libjs-underscore libjson-c-dev libjsoncpp-dev libkml-dev libkmlconvenience1
#   libkmlregionator1 libkmlxsd1 liblwres160 libmbim-glib4 libmbim-proxy
#   libminizip-dev libmm-glib0 libmysqlclient-dev libnetcdf-cxx-legacy-dev
#   libnetcdf-dev libnl-genl-3-200 libnss-mdns libogdi3.2-dev libopenjp2-7-dev
#   libopenni-dev libopenni-sensor-pointclouds0 libopenni0 libopenni2-0
#   libopenni2-dev liborc-0.4-0 libpam-cap libpcl-apps1.8 libpcl-common1.8
#   libpcl-dev libpcl-features1.8 libpcl-filters1.8 libpcl-io1.8
#   libpcl-kdtree1.8 libpcl-keypoints1.8 libpcl-ml1.8 libpcl-octree1.8
#   libpcl-outofcore1.8 libpcl-people1.8 libpcl-recognition1.8
#   libpcl-registration1.8 libpcl-sample-consensus1.8 libpcl-search1.8
#   libpcl-segmentation1.8 libpcl-stereo1.8 libpcl-surface1.8 libpcl-tracking1.8
#   libpcl-visualization1.8 libpoppler-dev libpoppler-private-dev libpq-dev
#   libproj-dev libqhull-dev libqhull-r7 libqmi-glib5 libqmi-proxy
#   libqt5designer5 libqt5designercomponents5 libqt5help5 libqt5opengl5
#   libqt5opengl5-dev libqt5positioning5 libqt5qml5 libqt5quick5
#   libqt5quickparticles5 libqt5quicktest5 libqt5quickwidgets5 libqt5sensors5
#   libqt5sql5-sqlite libqt5webchannel5 libqt5webkit5 libqt5webkit5-dev
#   libspatialite-dev libsqlite3-dev libsuperlu-dev libtheora-dev
#   libtinyxml2.6.2v5 liburiparser-dev libvisual-0.4-0 libvtk6-dev libvtk6-java
#   libvtk6-jni libvtk6-qt-dev libvtk6.3-qt libwebp-dev libwoff1 libxerces-c-dev
#   modemmanager openni-utils python-asn1crypto python-attr python-autobahn
#   python-automat python-cbor python-cffi-backend python-click python-colorama
#   python-concurrent.futures python-constantly python-cryptography
#   python-enum34 python-hyperlink python-idna python-incremental
#   python-ipaddress python-lz4 python-mpi4py python-nacl python-olefile
#   python-openssl python-pam python-pil python-pkg-resources python-pyasn1
#   python-pyasn1-modules python-qrcode python-serial python-service-identity
#   python-six python-snappy python-trie python-trollius python-twisted
#   python-twisted-bin python-twisted-core python-txaio python-u-msgpack
#   python-ubjson python-vtk6 python-wsaccel python-zope.interface qt5-assistant
#   qt5-qmltooling-plugins qtdeclarative5-dev qttools5-dev qttools5-dev-tools
#   qttools5-private-dev tcl-vtk6 unixodbc-dev usb-modeswitch
#   usb-modeswitch-data vtk6 wpasupplicant
# 0 upgraded, 190 newly installed, 0 to remove and 12 not upgraded.
# Need to get 83.5 MB of archives.
# After this operation, 488 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdaemon0 amd64 0.14-6 [16.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtinyxml2.6.2v5 amd64 2.6.2-4 [29.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenni0 amd64 1.5.4.0-14build1 [276 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcap2-bin amd64 1:2.25-1.2 [20.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer1.0-0 amd64 1.14.5-0ubuntu1~18.04.1 [865 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 liborc-0.4-0 amd64 1:0.4.28-1 [137 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.14.5-0ubuntu1~18.04.1 [688 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhyphen0 amd64 2.8.8-5 [26.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5positioning5 amd64 5.9.5+dfsg-0ubuntu2 [131 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libqt5qml5 amd64 5.9.5-0ubuntu1.1 [1,242 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libqt5quick5 amd64 5.9.5-0ubuntu1.1 [1,201 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5sensors5 amd64 5.9.5-0ubuntu1 [113 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5webchannel5 amd64 5.9.5-0ubuntu1 [47.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbrotli1 amd64 1.0.3-1ubuntu1.3 [262 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwoff1 amd64 1.0.2-1build0.1 [43.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5webkit5 amd64 5.212.0~alpha2-7ubuntu1 [11.8 MB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libqt5quickparticles5 amd64 5.9.5-0ubuntu1.1 [167 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libqt5quicktest5 amd64 5.9.5-0ubuntu1.1 [59.1 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libqt5quickwidgets5 amd64 5.9.5-0ubuntu1.1 [35.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 qt5-qmltooling-plugins amd64 5.9.5-0ubuntu1.1 [158 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 qtdeclarative5-dev amd64 5.9.5-0ubuntu1.1 [529 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5webkit5-dev amd64 5.212.0~alpha2-7ubuntu1 [52.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpam-cap amd64 1:2.25-1.2 [7,268 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libisc169 amd64 1:9.11.3+dfsg-1ubuntu1.13 [238 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgeoip1 amd64 1.6.12-1 [71.8 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdns1100 amd64 1:9.11.3+dfsg-1ubuntu1.13 [966 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libisccc160 amd64 1:9.11.3+dfsg-1ubuntu1.13 [17.9 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libisccfg160 amd64 1:9.11.3+dfsg-1ubuntu1.13 [48.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbind9-160 amd64 1:9.11.3+dfsg-1ubuntu1.13 [27.6 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblwres160 amd64 1:9.11.3+dfsg-1ubuntu1.13 [34.7 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 bind9-host amd64 1:9.11.3+dfsg-1ubuntu1.13 [53.5 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 geoip-database all 20180315-1 [2,090 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-core7 amd64 0.7-3.1ubuntu1.2 [81.1 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 avahi-daemon amd64 0.7-3.1ubuntu1.2 [62.3 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cython amd64 0.26.1-0.4 [1,874 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmysqlclient-dev amd64 5.7.32-0ubuntu0.18.04.1 [988 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 default-libmysqlclient-dev amd64 1.0.4 [3,736 B]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-glib1 amd64 0.7-3.1ubuntu1.2 [7,720 B]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgeoclue-2-0 amd64 2.4.7-1ubuntu1 [25.6 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmm-glib0 amd64 1.10.0-1~ubuntu18.04.2 [179 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 geoclue-2.0 amd64 2.4.7-1ubuntu1 [80.6 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdparanoia0 amd64 3.10.2+debian-13 [46.7 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvisual-0.4-0 amd64 0.4.0-11 [99.2 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-plugins-base amd64 1.14.5-0ubuntu1~18.04.1 [587 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 iio-sensor-proxy amd64 2.4-2 [45.0 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblas3 amd64 3.7.1-4ubuntu1 [140 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblas-dev amd64 3.7.1-4ubuntu1 [143 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libarpack2-dev amd64 3.5.0+real-2 [97.3 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsuperlu-dev amd64 5.2.1+dfsg1-3 [16.3 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libarmadillo-dev amd64 1:8.400.0+dfsg-2 [340 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdapserver7v5 amd64 3.19.1-2build1 [22.2 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdap-dev amd64 3.19.1-2build1 [710 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libflann1.9 amd64 1.9.1+dfsg-2 [641 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libflann-dev amd64 1.9.1+dfsg-2 [614 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfyba-dev amd64 4.1.1-3 [436 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgeos-dev amd64 3.6.2-1build2 [73.1 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgif-dev amd64 5.1.4-2ubuntu0.1 [20.6 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-glx amd64 20.0.8-0ubuntu1~18.04.1 [5,532 B]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgl2ps-dev amd64 1.4.0+dfsg1-1 [240 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-underscore all 1.8.3~dfsg-1 [59.9 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-sphinxdoc all 1.6.7-1ubuntu1 [85.6 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libkmlconvenience1 amd64 1.3.0-5 [43.1 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libkmlregionator1 amd64 1.3.0-5 [19.0 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libkmlxsd1 amd64 1.3.0-5 [29.5 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmbim-glib4 amd64 1.18.0-1~ubuntu18.04.1 [91.4 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmbim-proxy amd64 1.18.0-1~ubuntu18.04.1 [5,572 B]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libminizip-dev amd64 1.1-8build1 [26.7 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libnetcdf-dev amd64 1:4.6.0-2build1 [37.6 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libnetcdf-cxx-legacy-dev amd64 4.2-8 [53.3 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnl-genl-3-200 amd64 3.2.29-0ubuntu3 [11.2 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnss-mdns amd64 0.10-8ubuntu1 [21.2 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenni-dev amd64 1.5.4.0-14build1 [138 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/universe amd64 openni-utils amd64 1.5.4.0-14build1 [115 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenni-sensor-pointclouds0 amd64 5.1.0.41.9-1 [297 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenni2-0 amd64 2.2.0.33+dfsg-10 [398 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenni2-dev amd64 2.2.0.33+dfsg-10 [73.0 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-dev amd64 0.62.0-2ubuntu2.10 [4,608 B]
# Get:80 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-private-dev amd64 0.62.0-2ubuntu2.10 [169 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpq-dev amd64 10.14-0ubuntu0.18.04.1 [218 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqhull-r7 amd64 2015.2-4 [149 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqhull-dev amd64 2015.2-4 [357 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqmi-glib5 amd64 1.22.0-1.2~ubuntu18.04.1 [494 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqmi-proxy amd64 1.22.0-1.2~ubuntu18.04.1 [5,632 B]
# Get:86 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5designer5 amd64 5.9.5-0ubuntu1 [2,761 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5designercomponents5 amd64 5.9.5-0ubuntu1 [692 kB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5help5 amd64 5.9.5-0ubuntu1 [133 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqt5opengl5 amd64 5.9.5+dfsg-0ubuntu2.5 [132 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqt5opengl5-dev amd64 5.9.5+dfsg-0ubuntu2.5 [36.1 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqt5sql5-sqlite amd64 5.9.5+dfsg-0ubuntu2.5 [40.2 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsqlite3-dev amd64 3.22.0-1ubuntu0.4 [633 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtheora-dev amd64 1.1.1+dfsg.1-14 [186 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liburiparser-dev amd64 0.8.4-1 [10.0 kB]
# Get:95 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libeigen3-dev all 3.3.4-4 [810 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libepsilon-dev amd64 0.9.2+dfsg-2 [49.3 kB]
# Get:97 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfreexl-dev amd64 1.0.5-1 [30.9 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgeotiff-dev amd64 1.4.2-2build1 [82.6 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhdf4-alt-dev amd64 4.2.13-2 [368 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjson-c-dev amd64 0.12.1-1.3ubuntu0.3 [31.9 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libkml-dev amd64 1.3.0-5 [933 kB]
# Get:102 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libproj-dev amd64 4.9.3-2 [199 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libogdi3.2-dev amd64 3.2.0+ds-2 [23.6 kB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopenjp2-7-dev amd64 2.3.0-2build0.18.04.1 [26.6 kB]
# Get:105 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialite-dev amd64 4.3.0a-5build1 [1,323 kB]
# Get:106 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwebp-dev amd64 0.6.1-2 [267 kB]
# Get:107 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxerces-c-dev amd64 3.2.0+debian-2 [1,627 kB]
# Get:108 http://archive.ubuntu.com/ubuntu bionic/main amd64 unixodbc-dev amd64 2.3.4-1.1ubuntu3 [217 kB]
# Get:109 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgdal-dev amd64 2.2.3+dfsg-2 [6,369 kB]
# Get:110 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhdf5-openmpi-dev amd64 1.10.0-patch1+docs-4 [2,392 kB]
# Get:111 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhdf5-mpi-dev amd64 1.10.0-patch1+docs-4 [3,074 B]
# Get:112 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjsoncpp-dev amd64 1.7.4-3 [85.3 kB]
# Get:113 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvtk6.3-qt amd64 6.3.0+dfsg1-11build1 [244 kB]
# Get:114 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvtk6-jni amd64 6.3.0+dfsg1-11build1 [4,348 kB]
# Get:115 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvtk6-java amd64 6.3.0+dfsg1-11build1 [3,301 kB]
# Get:116 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-cbor amd64 1.0.0-1 [20.7 kB]
# Get:117 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-concurrent.futures all 3.2.0-1 [34.2 kB]
# Get:118 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-lz4 amd64 0.10.1+dfsg1-0.2 [16.6 kB]
# Get:119 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-cffi-backend amd64 1.11.5-1 [63.4 kB]
# Get:120 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-six all 1.11.0-2 [11.3 kB]
# Get:121 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-nacl amd64 1.1.2-1build1 [27.8 kB]
# Get:122 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-asn1crypto all 0.24.0-1 [72.7 kB]
# Get:123 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-enum34 all 1.1.6-2 [34.8 kB]
# Get:124 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-idna all 2.6-1 [32.4 kB]
# Get:125 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-ipaddress all 1.0.17-1 [18.2 kB]
# Get:126 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-cryptography amd64 2.1.4-1ubuntu1.4 [276 kB]
# Get:127 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-openssl all 17.5.0-1ubuntu1 [41.3 kB]
# Get:128 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-pil amd64 5.1.0-1ubuntu0.3 [301 kB]
# Get:129 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-qrcode all 5.3-1 [25.3 kB]
# Get:130 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-attr all 17.4.0-2 [23.7 kB]
# Get:131 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pyasn1 all 0.4.2-3 [46.7 kB]
# Get:132 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pyasn1-modules all 0.2.1-0.2 [32.8 kB]
# Get:133 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-service-identity all 16.0.0-2 [9,318 B]
# Get:134 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-snappy amd64 0.5-1.1build2 [10.8 kB]
# Get:135 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-trie all 0.2+ds-1 [7,076 B]
# Get:136 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-trollius all 2.1~b1-5 [83.9 kB]
# Get:137 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-twisted-bin amd64 17.9.0-2ubuntu0.1 [14.8 kB]
# Get:138 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pkg-resources all 39.0.1-2 [128 kB]
# Get:139 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-zope.interface amd64 4.3.2-1build2 [82.2 kB]
# Get:140 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-automat all 0.6.0-1 [25.1 kB]
# Get:141 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-constantly all 15.1.0-1 [7,960 B]
# Get:142 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-hyperlink all 17.3.1-2 [27.5 kB]
# Get:143 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-incremental all 16.10.1-3 [14.4 kB]
# Get:144 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-twisted-core all 17.9.0-2ubuntu0.1 [2,009 kB]
# Get:145 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-twisted all 17.9.0-2ubuntu0.1 [3,728 B]
# Get:146 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-txaio all 2.8.1-1 [18.2 kB]
# Get:147 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-u-msgpack all 2.1-1 [7,268 B]
# Get:148 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-ubjson amd64 0.8.5-2build1 [95.0 kB]
# Get:149 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-wsaccel amd64 0.6.2-1 [37.5 kB]
# Get:150 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-autobahn all 17.10.1+dfsg1-2 [158 kB]
# Get:151 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-mpi4py amd64 2.0.0-3 [421 kB]
# Get:152 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-vtk6 amd64 6.3.0+dfsg1-11build1 [283 kB]
# Get:153 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tcl-vtk6 amd64 6.3.0+dfsg1-11build1 [142 kB]
# Get:154 http://archive.ubuntu.com/ubuntu bionic/universe amd64 vtk6 amd64 6.3.0+dfsg1-11build1 [180 kB]
# Get:155 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvtk6-dev amd64 6.3.0+dfsg1-11build1 [2,145 kB]
# Get:156 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qt5-assistant amd64 5.9.5-0ubuntu1 [747 kB]
# Get:157 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qttools5-dev-tools amd64 5.9.5-0ubuntu1 [1,435 kB]
# Get:158 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qttools5-dev amd64 5.9.5-0ubuntu1 [184 kB]
# Get:159 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qttools5-private-dev amd64 5.9.5-0ubuntu1 [69.5 kB]
# Get:160 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvtk6-qt-dev amd64 6.3.0+dfsg1-11build1 [37.5 kB]
# Get:161 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 modemmanager amd64 1.10.0-1~ubuntu18.04.2 [728 kB]
# Get:162 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-colorama all 0.3.7-1 [22.6 kB]
# Get:163 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-click all 6.7-3 [56.4 kB]
# Get:164 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-olefile all 0.45.1-1 [33.2 kB]
# Get:165 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pam amd64 0.4.2-13.2ubuntu4 [9,856 B]
# Get:166 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-serial all 3.4-2 [71.9 kB]
# Get:167 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 wpasupplicant amd64 2:2.6-15ubuntu2.5 [954 kB]
# Get:168 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-common1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [182 kB]
# Get:169 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-kdtree1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [207 kB]
# Get:170 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-octree1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [202 kB]
# Get:171 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-sample-consensus1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [1,209 kB]
# Get:172 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-search1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [233 kB]
# Get:173 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-filters1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [1,002 kB]
# Get:174 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-features1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [3,260 kB]
# Get:175 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-ml1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [67.1 kB]
# Get:176 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-segmentation1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [1,469 kB]
# Get:177 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-surface1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [741 kB]
# Get:178 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-apps1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [225 kB]
# Get:179 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-io1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [589 kB]
# Get:180 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-keypoints1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [258 kB]
# Get:181 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-outofcore1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [45.5 kB]
# Get:182 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-people1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [20.3 kB]
# Get:183 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-recognition1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [770 kB]
# Get:184 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-registration1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [351 kB]
# Get:185 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-stereo1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [68.9 kB]
# Get:186 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-tracking1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [394 kB]
# Get:187 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-visualization1.8 amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [332 kB]
# Get:188 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpcl-dev amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [1,077 kB]
# Get:189 http://archive.ubuntu.com/ubuntu bionic/main amd64 usb-modeswitch-data all 20170806-2 [30.7 kB]
# Get:190 http://archive.ubuntu.com/ubuntu bionic/main amd64 usb-modeswitch amd64 2.5.2+repack0-2ubuntu1 [53.6 kB]
# Fetched 83.5 MB in 5s (15.4 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libdaemon0:amd64.
# (Reading database ... 144786 files and directories currently installed.)
# Preparing to unpack .../000-libdaemon0_0.14-6_amd64.deb ...
# Unpacking libdaemon0:amd64 (0.14-6) ...
# Selecting previously unselected package libtinyxml2.6.2v5:amd64.
# Preparing to unpack .../001-libtinyxml2.6.2v5_2.6.2-4_amd64.deb ...
# Unpacking libtinyxml2.6.2v5:amd64 (2.6.2-4) ...
# Selecting previously unselected package libopenni0.
# Preparing to unpack .../002-libopenni0_1.5.4.0-14build1_amd64.deb ...
# Unpacking libopenni0 (1.5.4.0-14build1) ...
# Selecting previously unselected package libcap2-bin.
# Preparing to unpack .../003-libcap2-bin_1%3a2.25-1.2_amd64.deb ...
# Unpacking libcap2-bin (1:2.25-1.2) ...
# Selecting previously unselected package libgstreamer1.0-0:amd64.
# Preparing to unpack .../004-libgstreamer1.0-0_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../005-liborc-0.4-0_1%3a0.4.28-1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../006-libgstreamer-plugins-base1.0-0_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../007-libhyphen0_2.8.8-5_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-5) ...
# Selecting previously unselected package libqt5positioning5:amd64.
# Preparing to unpack .../008-libqt5positioning5_5.9.5+dfsg-0ubuntu2_amd64.deb ...
# Unpacking libqt5positioning5:amd64 (5.9.5+dfsg-0ubuntu2) ...
# Selecting previously unselected package libqt5qml5:amd64.
# Preparing to unpack .../009-libqt5qml5_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking libqt5qml5:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package libqt5quick5:amd64.
# Preparing to unpack .../010-libqt5quick5_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking libqt5quick5:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package libqt5sensors5:amd64.
# Preparing to unpack .../011-libqt5sensors5_5.9.5-0ubuntu1_amd64.deb ...
# Unpacking libqt5sensors5:amd64 (5.9.5-0ubuntu1) ...
# Selecting previously unselected package libqt5webchannel5:amd64.
# Preparing to unpack .../012-libqt5webchannel5_5.9.5-0ubuntu1_amd64.deb ...
# Unpacking libqt5webchannel5:amd64 (5.9.5-0ubuntu1) ...
# Selecting previously unselected package libbrotli1:amd64.
# Preparing to unpack .../013-libbrotli1_1.0.3-1ubuntu1.3_amd64.deb ...
# Unpacking libbrotli1:amd64 (1.0.3-1ubuntu1.3) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../014-libwoff1_1.0.2-1build0.1_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build0.1) ...
# Selecting previously unselected package libqt5webkit5:amd64.
# Preparing to unpack .../015-libqt5webkit5_5.212.0~alpha2-7ubuntu1_amd64.deb ...
# Unpacking libqt5webkit5:amd64 (5.212.0~alpha2-7ubuntu1) ...
# Selecting previously unselected package libqt5quickparticles5:amd64.
# Preparing to unpack .../016-libqt5quickparticles5_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking libqt5quickparticles5:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package libqt5quicktest5:amd64.
# Preparing to unpack .../017-libqt5quicktest5_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking libqt5quicktest5:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package libqt5quickwidgets5:amd64.
# Preparing to unpack .../018-libqt5quickwidgets5_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking libqt5quickwidgets5:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package qt5-qmltooling-plugins:amd64.
# Preparing to unpack .../019-qt5-qmltooling-plugins_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking qt5-qmltooling-plugins:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package qtdeclarative5-dev:amd64.
# Preparing to unpack .../020-qtdeclarative5-dev_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking qtdeclarative5-dev:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package libqt5webkit5-dev:amd64.
# Preparing to unpack .../021-libqt5webkit5-dev_5.212.0~alpha2-7ubuntu1_amd64.deb ...
# Unpacking libqt5webkit5-dev:amd64 (5.212.0~alpha2-7ubuntu1) ...
# Selecting previously unselected package libpam-cap:amd64.
# Preparing to unpack .../022-libpam-cap_1%3a2.25-1.2_amd64.deb ...
# Unpacking libpam-cap:amd64 (1:2.25-1.2) ...
# Selecting previously unselected package libisc169:amd64.
# Preparing to unpack .../023-libisc169_1%3a9.11.3+dfsg-1ubuntu1.13_amd64.deb ...
# Unpacking libisc169:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Selecting previously unselected package libgeoip1:amd64.
# Preparing to unpack .../024-libgeoip1_1.6.12-1_amd64.deb ...
# Unpacking libgeoip1:amd64 (1.6.12-1) ...
# Selecting previously unselected package libdns1100:amd64.
# Preparing to unpack .../025-libdns1100_1%3a9.11.3+dfsg-1ubuntu1.13_amd64.deb ...
# Unpacking libdns1100:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Selecting previously unselected package libisccc160:amd64.
# Preparing to unpack .../026-libisccc160_1%3a9.11.3+dfsg-1ubuntu1.13_amd64.deb ...
# Unpacking libisccc160:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Selecting previously unselected package libisccfg160:amd64.
# Preparing to unpack .../027-libisccfg160_1%3a9.11.3+dfsg-1ubuntu1.13_amd64.deb ...
# Unpacking libisccfg160:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Selecting previously unselected package libbind9-160:amd64.
# Preparing to unpack .../028-libbind9-160_1%3a9.11.3+dfsg-1ubuntu1.13_amd64.deb ...
# Unpacking libbind9-160:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Selecting previously unselected package liblwres160:amd64.
# Preparing to unpack .../029-liblwres160_1%3a9.11.3+dfsg-1ubuntu1.13_amd64.deb ...
# Unpacking liblwres160:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Selecting previously unselected package bind9-host.
# Preparing to unpack .../030-bind9-host_1%3a9.11.3+dfsg-1ubuntu1.13_amd64.deb ...
# Unpacking bind9-host (1:9.11.3+dfsg-1ubuntu1.13) ...
# Selecting previously unselected package geoip-database.
# Preparing to unpack .../031-geoip-database_20180315-1_all.deb ...
# Unpacking geoip-database (20180315-1) ...
# Selecting previously unselected package libavahi-core7:amd64.
# Preparing to unpack .../032-libavahi-core7_0.7-3.1ubuntu1.2_amd64.deb ...
# Unpacking libavahi-core7:amd64 (0.7-3.1ubuntu1.2) ...
# Selecting previously unselected package avahi-daemon.
# Preparing to unpack .../033-avahi-daemon_0.7-3.1ubuntu1.2_amd64.deb ...
# Unpacking avahi-daemon (0.7-3.1ubuntu1.2) ...
# Selecting previously unselected package cython.
# Preparing to unpack .../034-cython_0.26.1-0.4_amd64.deb ...
# Unpacking cython (0.26.1-0.4) ...
# Selecting previously unselected package libmysqlclient-dev.
# Preparing to unpack .../035-libmysqlclient-dev_5.7.32-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libmysqlclient-dev (5.7.32-0ubuntu0.18.04.1) ...
# Selecting previously unselected package default-libmysqlclient-dev:amd64.
# Preparing to unpack .../036-default-libmysqlclient-dev_1.0.4_amd64.deb ...
# Unpacking default-libmysqlclient-dev:amd64 (1.0.4) ...
# Selecting previously unselected package libavahi-glib1:amd64.
# Preparing to unpack .../037-libavahi-glib1_0.7-3.1ubuntu1.2_amd64.deb ...
# Unpacking libavahi-glib1:amd64 (0.7-3.1ubuntu1.2) ...
# Selecting previously unselected package libgeoclue-2-0:amd64.
# Preparing to unpack .../038-libgeoclue-2-0_2.4.7-1ubuntu1_amd64.deb ...
# Unpacking libgeoclue-2-0:amd64 (2.4.7-1ubuntu1) ...
# Selecting previously unselected package libmm-glib0:amd64.
# Preparing to unpack .../039-libmm-glib0_1.10.0-1~ubuntu18.04.2_amd64.deb ...
# Unpacking libmm-glib0:amd64 (1.10.0-1~ubuntu18.04.2) ...
# Selecting previously unselected package geoclue-2.0.
# Preparing to unpack .../040-geoclue-2.0_2.4.7-1ubuntu1_amd64.deb ...
# Unpacking geoclue-2.0 (2.4.7-1ubuntu1) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../041-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../042-libvisual-0.4-0_0.4.0-11_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-11) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../043-gstreamer1.0-plugins-base_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package iio-sensor-proxy.
# Preparing to unpack .../044-iio-sensor-proxy_2.4-2_amd64.deb ...
# Unpacking iio-sensor-proxy (2.4-2) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../045-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libblas3:amd64.
# Preparing to unpack .../046-libblas3_3.7.1-4ubuntu1_amd64.deb ...
# Unpacking libblas3:amd64 (3.7.1-4ubuntu1) ...
# Selecting previously unselected package libblas-dev:amd64.
# Preparing to unpack .../047-libblas-dev_3.7.1-4ubuntu1_amd64.deb ...
# Unpacking libblas-dev:amd64 (3.7.1-4ubuntu1) ...
# Selecting previously unselected package libarpack2-dev:amd64.
# Preparing to unpack .../048-libarpack2-dev_3.5.0+real-2_amd64.deb ...
# Unpacking libarpack2-dev:amd64 (3.5.0+real-2) ...
# Selecting previously unselected package libsuperlu-dev:amd64.
# Preparing to unpack .../049-libsuperlu-dev_5.2.1+dfsg1-3_amd64.deb ...
# Unpacking libsuperlu-dev:amd64 (5.2.1+dfsg1-3) ...
# Selecting previously unselected package libarmadillo-dev.
# Preparing to unpack .../050-libarmadillo-dev_1%3a8.400.0+dfsg-2_amd64.deb ...
# Unpacking libarmadillo-dev (1:8.400.0+dfsg-2) ...
# Selecting previously unselected package libdapserver7v5:amd64.
# Preparing to unpack .../051-libdapserver7v5_3.19.1-2build1_amd64.deb ...
# Unpacking libdapserver7v5:amd64 (3.19.1-2build1) ...
# Selecting previously unselected package libdap-dev:amd64.
# Preparing to unpack .../052-libdap-dev_3.19.1-2build1_amd64.deb ...
# Unpacking libdap-dev:amd64 (3.19.1-2build1) ...
# Selecting previously unselected package libflann1.9:amd64.
# Preparing to unpack .../053-libflann1.9_1.9.1+dfsg-2_amd64.deb ...
# Unpacking libflann1.9:amd64 (1.9.1+dfsg-2) ...
# Selecting previously unselected package libflann-dev.
# Preparing to unpack .../054-libflann-dev_1.9.1+dfsg-2_amd64.deb ...
# Unpacking libflann-dev (1.9.1+dfsg-2) ...
# Selecting previously unselected package libfyba-dev:amd64.
# Preparing to unpack .../055-libfyba-dev_4.1.1-3_amd64.deb ...
# Unpacking libfyba-dev:amd64 (4.1.1-3) ...
# Selecting previously unselected package libgeos-dev.
# Preparing to unpack .../056-libgeos-dev_3.6.2-1build2_amd64.deb ...
# Unpacking libgeos-dev (3.6.2-1build2) ...
# Selecting previously unselected package libgif-dev.
# Preparing to unpack .../057-libgif-dev_5.1.4-2ubuntu0.1_amd64.deb ...
# Unpacking libgif-dev (5.1.4-2ubuntu0.1) ...
# Selecting previously unselected package libgl1-mesa-glx:amd64.
# Preparing to unpack .../058-libgl1-mesa-glx_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgl1-mesa-glx:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libgl2ps-dev.
# Preparing to unpack .../059-libgl2ps-dev_1.4.0+dfsg1-1_amd64.deb ...
# Unpacking libgl2ps-dev (1.4.0+dfsg1-1) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../060-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../061-libjs-underscore_1.8.3~dfsg-1_all.deb ...
# Unpacking libjs-underscore (1.8.3~dfsg-1) ...
# Selecting previously unselected package libjs-sphinxdoc.
# Preparing to unpack .../062-libjs-sphinxdoc_1.6.7-1ubuntu1_all.deb ...
# Unpacking libjs-sphinxdoc (1.6.7-1ubuntu1) ...
# Selecting previously unselected package libkmlconvenience1:amd64.
# Preparing to unpack .../063-libkmlconvenience1_1.3.0-5_amd64.deb ...
# Unpacking libkmlconvenience1:amd64 (1.3.0-5) ...
# Selecting previously unselected package libkmlregionator1:amd64.
# Preparing to unpack .../064-libkmlregionator1_1.3.0-5_amd64.deb ...
# Unpacking libkmlregionator1:amd64 (1.3.0-5) ...
# Selecting previously unselected package libkmlxsd1:amd64.
# Preparing to unpack .../065-libkmlxsd1_1.3.0-5_amd64.deb ...
# Unpacking libkmlxsd1:amd64 (1.3.0-5) ...
# Selecting previously unselected package libmbim-glib4:amd64.
# Preparing to unpack .../066-libmbim-glib4_1.18.0-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libmbim-glib4:amd64 (1.18.0-1~ubuntu18.04.1) ...
# Selecting previously unselected package libmbim-proxy.
# Preparing to unpack .../067-libmbim-proxy_1.18.0-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libmbim-proxy (1.18.0-1~ubuntu18.04.1) ...
# Selecting previously unselected package libminizip-dev:amd64.
# Preparing to unpack .../068-libminizip-dev_1.1-8build1_amd64.deb ...
# Unpacking libminizip-dev:amd64 (1.1-8build1) ...
# Selecting previously unselected package libnetcdf-dev.
# Preparing to unpack .../069-libnetcdf-dev_1%3a4.6.0-2build1_amd64.deb ...
# Unpacking libnetcdf-dev (1:4.6.0-2build1) ...
# Selecting previously unselected package libnetcdf-cxx-legacy-dev.
# Preparing to unpack .../070-libnetcdf-cxx-legacy-dev_4.2-8_amd64.deb ...
# Unpacking libnetcdf-cxx-legacy-dev (4.2-8) ...
# Selecting previously unselected package libnl-genl-3-200:amd64.
# Preparing to unpack .../071-libnl-genl-3-200_3.2.29-0ubuntu3_amd64.deb ...
# Unpacking libnl-genl-3-200:amd64 (3.2.29-0ubuntu3) ...
# Selecting previously unselected package libnss-mdns:amd64.
# Preparing to unpack .../072-libnss-mdns_0.10-8ubuntu1_amd64.deb ...
# Unpacking libnss-mdns:amd64 (0.10-8ubuntu1) ...
# Selecting previously unselected package libopenni-dev.
# Preparing to unpack .../073-libopenni-dev_1.5.4.0-14build1_amd64.deb ...
# Unpacking libopenni-dev (1.5.4.0-14build1) ...
# Selecting previously unselected package openni-utils.
# Preparing to unpack .../074-openni-utils_1.5.4.0-14build1_amd64.deb ...
# Unpacking openni-utils (1.5.4.0-14build1) ...
# Selecting previously unselected package libopenni-sensor-pointclouds0.
# Preparing to unpack .../075-libopenni-sensor-pointclouds0_5.1.0.41.9-1_amd64.deb ...
# Unpacking libopenni-sensor-pointclouds0 (5.1.0.41.9-1) ...
# Selecting previously unselected package libopenni2-0.
# Preparing to unpack .../076-libopenni2-0_2.2.0.33+dfsg-10_amd64.deb ...
# Unpacking libopenni2-0 (2.2.0.33+dfsg-10) ...
# Selecting previously unselected package libopenni2-dev.
# Preparing to unpack .../077-libopenni2-dev_2.2.0.33+dfsg-10_amd64.deb ...
# Unpacking libopenni2-dev (2.2.0.33+dfsg-10) ...
# Selecting previously unselected package libpoppler-dev:amd64.
# Preparing to unpack .../078-libpoppler-dev_0.62.0-2ubuntu2.10_amd64.deb ...
# Unpacking libpoppler-dev:amd64 (0.62.0-2ubuntu2.10) ...
# Selecting previously unselected package libpoppler-private-dev:amd64.
# Preparing to unpack .../079-libpoppler-private-dev_0.62.0-2ubuntu2.10_amd64.deb ...
# Unpacking libpoppler-private-dev:amd64 (0.62.0-2ubuntu2.10) ...
# Selecting previously unselected package libpq-dev.
# Preparing to unpack .../080-libpq-dev_10.14-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libpq-dev (10.14-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libqhull-r7:amd64.
# Preparing to unpack .../081-libqhull-r7_2015.2-4_amd64.deb ...
# Unpacking libqhull-r7:amd64 (2015.2-4) ...
# Selecting previously unselected package libqhull-dev:amd64.
# Preparing to unpack .../082-libqhull-dev_2015.2-4_amd64.deb ...
# Unpacking libqhull-dev:amd64 (2015.2-4) ...
# Selecting previously unselected package libqmi-glib5:amd64.
# Preparing to unpack .../083-libqmi-glib5_1.22.0-1.2~ubuntu18.04.1_amd64.deb ...
# Unpacking libqmi-glib5:amd64 (1.22.0-1.2~ubuntu18.04.1) ...
# Selecting previously unselected package libqmi-proxy.
# Preparing to unpack .../084-libqmi-proxy_1.22.0-1.2~ubuntu18.04.1_amd64.deb ...
# Unpacking libqmi-proxy (1.22.0-1.2~ubuntu18.04.1) ...
# Selecting previously unselected package libqt5designer5:amd64.
# Preparing to unpack .../085-libqt5designer5_5.9.5-0ubuntu1_amd64.deb ...
# Unpacking libqt5designer5:amd64 (5.9.5-0ubuntu1) ...
# Selecting previously unselected package libqt5designercomponents5:amd64.
# Preparing to unpack .../086-libqt5designercomponents5_5.9.5-0ubuntu1_amd64.deb ...
# Unpacking libqt5designercomponents5:amd64 (5.9.5-0ubuntu1) ...
# Selecting previously unselected package libqt5help5:amd64.
# Preparing to unpack .../087-libqt5help5_5.9.5-0ubuntu1_amd64.deb ...
# Unpacking libqt5help5:amd64 (5.9.5-0ubuntu1) ...
# Selecting previously unselected package libqt5opengl5:amd64.
# Preparing to unpack .../088-libqt5opengl5_5.9.5+dfsg-0ubuntu2.5_amd64.deb ...
# Unpacking libqt5opengl5:amd64 (5.9.5+dfsg-0ubuntu2.5) ...
# Selecting previously unselected package libqt5opengl5-dev:amd64.
# Preparing to unpack .../089-libqt5opengl5-dev_5.9.5+dfsg-0ubuntu2.5_amd64.deb ...
# Unpacking libqt5opengl5-dev:amd64 (5.9.5+dfsg-0ubuntu2.5) ...
# Selecting previously unselected package libqt5sql5-sqlite:amd64.
# Preparing to unpack .../090-libqt5sql5-sqlite_5.9.5+dfsg-0ubuntu2.5_amd64.deb ...
# Unpacking libqt5sql5-sqlite:amd64 (5.9.5+dfsg-0ubuntu2.5) ...
# Selecting previously unselected package libsqlite3-dev:amd64.
# Preparing to unpack .../091-libsqlite3-dev_3.22.0-1ubuntu0.4_amd64.deb ...
# Unpacking libsqlite3-dev:amd64 (3.22.0-1ubuntu0.4) ...
# Selecting previously unselected package libtheora-dev:amd64.
# Preparing to unpack .../092-libtheora-dev_1.1.1+dfsg.1-14_amd64.deb ...
# Unpacking libtheora-dev:amd64 (1.1.1+dfsg.1-14) ...
# Selecting previously unselected package liburiparser-dev.
# Preparing to unpack .../093-liburiparser-dev_0.8.4-1_amd64.deb ...
# Unpacking liburiparser-dev (0.8.4-1) ...
# Selecting previously unselected package libeigen3-dev.
# Preparing to unpack .../094-libeigen3-dev_3.3.4-4_all.deb ...
# Unpacking libeigen3-dev (3.3.4-4) ...
# Selecting previously unselected package libepsilon-dev:amd64.
# Preparing to unpack .../095-libepsilon-dev_0.9.2+dfsg-2_amd64.deb ...
# Unpacking libepsilon-dev:amd64 (0.9.2+dfsg-2) ...
# Selecting previously unselected package libfreexl-dev:amd64.
# Preparing to unpack .../096-libfreexl-dev_1.0.5-1_amd64.deb ...
# Unpacking libfreexl-dev:amd64 (1.0.5-1) ...
# Selecting previously unselected package libgeotiff-dev:amd64.
# Preparing to unpack .../097-libgeotiff-dev_1.4.2-2build1_amd64.deb ...
# Unpacking libgeotiff-dev:amd64 (1.4.2-2build1) ...
# Selecting previously unselected package libhdf4-alt-dev.
# Preparing to unpack .../098-libhdf4-alt-dev_4.2.13-2_amd64.deb ...
# Unpacking libhdf4-alt-dev (4.2.13-2) ...
# Selecting previously unselected package libjson-c-dev:amd64.
# Preparing to unpack .../099-libjson-c-dev_0.12.1-1.3ubuntu0.3_amd64.deb ...
# Unpacking libjson-c-dev:amd64 (0.12.1-1.3ubuntu0.3) ...
# Selecting previously unselected package libkml-dev:amd64.
# Preparing to unpack .../100-libkml-dev_1.3.0-5_amd64.deb ...
# Unpacking libkml-dev:amd64 (1.3.0-5) ...
# Selecting previously unselected package libproj-dev:amd64.
# Preparing to unpack .../101-libproj-dev_4.9.3-2_amd64.deb ...
# Unpacking libproj-dev:amd64 (4.9.3-2) ...
# Selecting previously unselected package libogdi3.2-dev.
# Preparing to unpack .../102-libogdi3.2-dev_3.2.0+ds-2_amd64.deb ...
# Unpacking libogdi3.2-dev (3.2.0+ds-2) ...
# Selecting previously unselected package libopenjp2-7-dev.
# Preparing to unpack .../103-libopenjp2-7-dev_2.3.0-2build0.18.04.1_amd64.deb ...
# Unpacking libopenjp2-7-dev (2.3.0-2build0.18.04.1) ...
# Selecting previously unselected package libspatialite-dev:amd64.
# Preparing to unpack .../104-libspatialite-dev_4.3.0a-5build1_amd64.deb ...
# Unpacking libspatialite-dev:amd64 (4.3.0a-5build1) ...
# Selecting previously unselected package libwebp-dev:amd64.
# Preparing to unpack .../105-libwebp-dev_0.6.1-2_amd64.deb ...
# Unpacking libwebp-dev:amd64 (0.6.1-2) ...
# Selecting previously unselected package libxerces-c-dev.
# ...
# Selecting previously unselected package libpcl-search1.8:amd64.
# Preparing to unpack .../171-libpcl-search1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-search1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-filters1.8:amd64.
# Preparing to unpack .../172-libpcl-filters1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-filters1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-features1.8:amd64.
# Preparing to unpack .../173-libpcl-features1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-features1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-ml1.8:amd64.
# Preparing to unpack .../174-libpcl-ml1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-ml1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-segmentation1.8:amd64.
# Preparing to unpack .../175-libpcl-segmentation1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-segmentation1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-surface1.8:amd64.
# Preparing to unpack .../176-libpcl-surface1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-surface1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-apps1.8:amd64.
# Preparing to unpack .../177-libpcl-apps1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-apps1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-io1.8:amd64.
# Preparing to unpack .../178-libpcl-io1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-io1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-keypoints1.8:amd64.
# Preparing to unpack .../179-libpcl-keypoints1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-keypoints1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-outofcore1.8:amd64.
# Preparing to unpack .../180-libpcl-outofcore1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-outofcore1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-people1.8:amd64.
# Preparing to unpack .../181-libpcl-people1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-people1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-recognition1.8:amd64.
# Preparing to unpack .../182-libpcl-recognition1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-recognition1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-registration1.8:amd64.
# Preparing to unpack .../183-libpcl-registration1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-registration1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-stereo1.8:amd64.
# Preparing to unpack .../184-libpcl-stereo1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-stereo1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-tracking1.8:amd64.
# Preparing to unpack .../185-libpcl-tracking1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-tracking1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-visualization1.8:amd64.
# Preparing to unpack .../186-libpcl-visualization1.8_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-visualization1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package libpcl-dev.
# Preparing to unpack .../187-libpcl-dev_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking libpcl-dev (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Selecting previously unselected package usb-modeswitch-data.
# Preparing to unpack .../188-usb-modeswitch-data_20170806-2_all.deb ...
# Unpacking usb-modeswitch-data (20170806-2) ...
# Selecting previously unselected package usb-modeswitch.
# Preparing to unpack .../189-usb-modeswitch_2.5.2+repack0-2ubuntu1_amd64.deb ...
# Unpacking usb-modeswitch (2.5.2+repack0-2ubuntu1) ...
# Setting up python-mpi4py (2.0.0-3) ...
# Setting up python-u-msgpack (2.1-1) ...
# Setting up libqt5qml5:amd64 (5.9.5-0ubuntu1.1) ...
# Setting up libjsoncpp-dev:amd64 (1.7.4-3) ...
# Setting up python-idna (2.6-1) ...
# Setting up libbrotli1:amd64 (1.0.3-1ubuntu1.3) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up libpcl-people1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libqt5quick5:amd64 (5.9.5-0ubuntu1.1) ...
# Setting up libisc169:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Setting up python-hyperlink (17.3.1-2) ...
# Setting up libqt5sensors5:amd64 (5.9.5-0ubuntu1) ...
# Setting up libgeotiff-dev:amd64 (1.4.2-2build1) ...
# Setting up libproj-dev:amd64 (4.9.3-2) ...
# Setting up libdaemon0:amd64 (0.14-6) ...
# Setting up libisccc160:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Setting up python-asn1crypto (0.24.0-1) ...
# Setting up libxerces-c-dev (3.2.0+debian-2) ...
# Setting up libflann1.9:amd64 (1.9.1+dfsg-2) ...
# Setting up unixodbc-dev:amd64 (2.3.4-1.1ubuntu3) ...
# Setting up libqt5quickwidgets5:amd64 (5.9.5-0ubuntu1.1) ...
# Setting up libmbim-glib4:amd64 (1.18.0-1~ubuntu18.04.1) ...
# Setting up libpq-dev (10.14-0ubuntu0.18.04.1) ...
# Setting up libpcl-common1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up python-lz4 (0.10.1+dfsg1-0.2) ...
# Setting up libpam-cap:amd64 (1:2.25-1.2) ...
# Setting up libpoppler-dev:amd64 (0.62.0-2ubuntu2.10) ...
# Setting up libtinyxml2.6.2v5:amd64 (2.6.2-4) ...
# Setting up python-attr (17.4.0-2) ...
# Setting up python-snappy (0.5-1.1build2) ...
# Setting up libjs-underscore (1.8.3~dfsg-1) ...
# Setting up libmysqlclient-dev (5.7.32-0ubuntu0.18.04.1) ...
# Setting up iio-sensor-proxy (2.4-2) ...
# Setting up libopenni2-0 (2.2.0.33+dfsg-10) ...
# Setting up libwoff1:amd64 (1.0.2-1build0.1) ...
# Setting up geoip-database (20180315-1) ...
# Setting up libpcl-sample-consensus1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libsqlite3-dev:amd64 (3.22.0-1ubuntu0.4) ...
# Setting up libtheora-dev:amd64 (1.1.1+dfsg.1-14) ...
# Setting up vtk6 (6.3.0+dfsg1-11build1) ...
# Setting up libcap2-bin (1:2.25-1.2) ...
# Setting up libeigen3-dev (3.3.4-4) ...
# Setting up libgif-dev (5.1.4-2ubuntu0.1) ...
# Setting up libepsilon-dev:amd64 (0.9.2+dfsg-2) ...
# Setting up python-pyasn1 (0.4.2-3) ...
# Setting up libpcl-ml1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libpcl-kdtree1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up python-twisted-bin:amd64 (17.9.0-2ubuntu0.1) ...
# Setting up libjs-sphinxdoc (1.6.7-1ubuntu1) ...
# Setting up libnl-genl-3-200:amd64 (3.2.29-0ubuntu3) ...
# Setting up libopenjp2-7-dev (2.3.0-2build0.18.04.1) ...
# Setting up libgeos-dev (3.6.2-1build2) ...
# Setting up python-colorama (0.3.7-1) ...
# Setting up libflann-dev (1.9.1+dfsg-2) ...
# Setting up libpcl-octree1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libgeoip1:amd64 (1.6.12-1) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up libminizip-dev:amd64 (1.1-8build1) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Setting up libkmlconvenience1:amd64 (1.3.0-5) ...
# Setting up python-pyasn1-modules (0.2.1-0.2) ...
# Setting up libqt5help5:amd64 (5.9.5-0ubuntu1) ...
# Setting up libqt5opengl5:amd64 (5.9.5+dfsg-0ubuntu2.5) ...
# Setting up libmbim-proxy (1.18.0-1~ubuntu18.04.1) ...
# Setting up cython (0.26.1-0.4) ...
# Setting up python-wsaccel (0.6.2-1) ...
# Setting up libogdi3.2-dev (3.2.0+ds-2) ...
# Setting up libwebp-dev:amd64 (0.6.1-2) ...
# Setting up usb-modeswitch-data (20170806-2) ...
# Setting up libhdf5-openmpi-dev (1.10.0-patch1+docs-4) ...
# update-alternatives: using /usr/bin/h5pcc.openmpi to provide /usr/bin/h5pcc (h5pcc) in auto mode
# Setting up libqt5sql5-sqlite:amd64 (5.9.5+dfsg-0ubuntu2.5) ...
# Setting up libqt5quickparticles5:amd64 (5.9.5-0ubuntu1.1) ...
# Setting up libkmlxsd1:amd64 (1.3.0-5) ...
# Setting up python-cffi-backend (1.11.5-1) ...
# Setting up libhyphen0:amd64 (2.8.8-5) ...
# Setting up python-incremental (16.10.1-3) ...
# Setting up libopenni0 (1.5.4.0-14build1) ...
# Setting up libblas3:amd64 (3.7.1-4ubuntu1) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-constantly (15.1.0-1) ...
# Setting up usb-modeswitch (2.5.2+repack0-2ubuntu1) ...
# Setting up python-cbor (1.0.0-1) ...
# Setting up libqt5quicktest5:amd64 (5.9.5-0ubuntu1.1) ...
# Setting up libmm-glib0:amd64 (1.10.0-1~ubuntu18.04.2) ...
# Setting up libdapserver7v5:amd64 (3.19.1-2build1) ...
# Setting up python-zope.interface (4.3.2-1build2) ...
# Setting up libgl1-mesa-glx:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libqt5positioning5:amd64 (5.9.5+dfsg-0ubuntu2) ...
# Setting up libkmlregionator1:amd64 (1.3.0-5) ...
# Setting up libpcl-stereo1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up python-enum34 (1.1.6-2) ...
# Setting up python-serial (3.4-2) ...
# Setting up libjson-c-dev:amd64 (0.12.1-1.3ubuntu0.3) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-11) ...
# Setting up libarpack2-dev:amd64 (3.5.0+real-2) ...
# Setting up libgl2ps-dev (1.4.0+dfsg1-1) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up liburiparser-dev (0.8.4-1) ...
# Setting up python-concurrent.futures (3.2.0-1) ...
# Setting up libopenni2-dev (2.2.0.33+dfsg-10) ...
# Setting up default-libmysqlclient-dev:amd64 (1.0.4) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Setting up libavahi-glib1:amd64 (0.7-3.1ubuntu1.2) ...
# Setting up javascript-common (11) ...
# Setting up libqt5webchannel5:amd64 (5.9.5-0ubuntu1) ...
# Setting up python-pam (0.4.2-13.2ubuntu4) ...
# Setting up libqt5designer5:amd64 (5.9.5-0ubuntu1) ...
# Setting up python-ubjson (0.8.5-2build1) ...
# Setting up libdns1100:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Setting up python-ipaddress (1.0.17-1) ...
# Setting up libspatialite-dev:amd64 (4.3.0a-5build1) ...
# Setting up python-trie (0.2+ds-1) ...
# Setting up libfyba-dev:amd64 (4.1.1-3) ...
# Setting up python-automat (0.6.0-1) ...
# Setting up libnetcdf-dev (1:4.6.0-2build1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.3) ...
# Setting up libqhull-r7:amd64 (2015.2-4) ...
# Setting up liblwres160:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Setting up qt5-qmltooling-plugins:amd64 (5.9.5-0ubuntu1.1) ...
# Setting up libpcl-outofcore1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libavahi-core7:amd64 (0.7-3.1ubuntu1.2) ...
# Setting up libfreexl-dev:amd64 (1.0.5-1) ...
# Setting up libpcl-search1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libnetcdf-cxx-legacy-dev (4.2-8) ...
# Setting up libpoppler-private-dev:amd64 (0.62.0-2ubuntu2.10) ...
# Setting up libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up python-nacl (1.1.2-1build1) ...
# Setting up libdap-dev:amd64 (3.19.1-2build1) ...
# Setting up python-trollius (2.1~b1-5) ...
# Setting up libblas-dev:amd64 (3.7.1-4ubuntu1) ...
# Setting up python-click (6.7-3) ...
# Setting up libqt5designercomponents5:amd64 (5.9.5-0ubuntu1) ...
# Setting up wpasupplicant (2:2.6-15ubuntu2.5) ...
# Created symlink /etc/systemd/system/dbus-fi.w1.wpa_supplicant1.service → /lib/systemd/system/wpa_supplicant.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/wpa_supplicant.service → /lib/systemd/system/wpa_supplicant.service.
# Setting up python-qrcode (5.3-1) ...
# update-alternatives: using /usr/bin/python2-qr to provide /usr/bin/qr (qr) in auto mode
# Setting up libqmi-glib5:amd64 (1.22.0-1.2~ubuntu18.04.1) ...
# Setting up libqmi-proxy (1.22.0-1.2~ubuntu18.04.1) ...
# Setting up libhdf5-mpi-dev (1.10.0-patch1+docs-4) ...
# Setting up libqt5opengl5-dev:amd64 (5.9.5+dfsg-0ubuntu2.5) ...
# Setting up qtdeclarative5-dev:amd64 (5.9.5-0ubuntu1.1) ...
# Setting up libqhull-dev:amd64 (2015.2-4) ...
# Setting up libpcl-io1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libkml-dev:amd64 (1.3.0-5) ...
# Setting up libhdf4-alt-dev (4.2.13-2) ...
# Setting up openni-utils (1.5.4.0-14build1) ...
# Setting up libopenni-dev (1.5.4.0-14build1) ...
# Setting up libisccfg160:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Setting up libsuperlu-dev:amd64 (5.2.1+dfsg1-3) ...
# Setting up python-cryptography (2.1.4-1ubuntu1.4) ...
# Setting up libpcl-filters1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libpcl-visualization1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libarmadillo-dev (1:8.400.0+dfsg-2) ...
# Setting up libpcl-tracking1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up libpcl-surface1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libgdal-dev (2.2.3+dfsg-2) ...
# Setting up python-openssl (17.5.0-1ubuntu1) ...
# Setting up libopenni-sensor-pointclouds0 (5.1.0.41.9-1) ...
# Setting up libqt5webkit5:amd64 (5.212.0~alpha2-7ubuntu1) ...
# Setting up modemmanager (1.10.0-1~ubuntu18.04.2) ...
# Created symlink /etc/systemd/system/dbus-org.freedesktop.ModemManager1.service → /lib/systemd/system/ModemManager.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/ModemManager.service → /lib/systemd/system/ModemManager.service.
# Setting up libbind9-160:amd64 (1:9.11.3+dfsg-1ubuntu1.13) ...
# Setting up libpcl-features1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libpcl-segmentation1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libvtk6.3-qt (6.3.0+dfsg1-11build1) ...
# Setting up libpcl-apps1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libpcl-registration1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libpcl-keypoints1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libpcl-recognition1.8:amd64 (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up qt5-assistant (5.9.5-0ubuntu1) ...
# Setting up python-service-identity (16.0.0-2) ...
# Setting up bind9-host (1:9.11.3+dfsg-1ubuntu1.13) ...
# Setting up libqt5webkit5-dev:amd64 (5.212.0~alpha2-7ubuntu1) ...
# Setting up libvtk6-jni (6.3.0+dfsg1-11build1) ...
# Setting up avahi-daemon (0.7-3.1ubuntu1.2) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of force-reload.
# Created symlink /etc/systemd/system/dbus-org.freedesktop.Avahi.service → /lib/systemd/system/avahi-daemon.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/avahi-daemon.service → /lib/systemd/system/avahi-daemon.service.
# Created symlink /etc/systemd/system/sockets.target.wants/avahi-daemon.socket → /lib/systemd/system/avahi-daemon.socket.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up python-twisted-core (17.9.0-2ubuntu0.1) ...
# Setting up tcl-vtk6 (6.3.0+dfsg1-11build1) ...
# Setting up qttools5-dev-tools (5.9.5-0ubuntu1) ...
# Setting up python-twisted (17.9.0-2ubuntu0.1) ...
# Setting up libnss-mdns:amd64 (0.10-8ubuntu1) ...
# First installation detected...
# Checking NSS setup...
# Setting up libvtk6-java (6.3.0+dfsg1-11build1) ...
# Setting up python-txaio (2.8.1-1) ...
# Setting up qttools5-dev:amd64 (5.9.5-0ubuntu1) ...
# Setting up qttools5-private-dev:amd64 (5.9.5-0ubuntu1) ...
# Setting up python-autobahn (17.10.1+dfsg1-2) ...
# Setting up python-vtk6 (6.3.0+dfsg1-11build1) ...
# Setting up libvtk6-dev (6.3.0+dfsg1-11build1) ...
# Setting up libvtk6-qt-dev (6.3.0+dfsg1-11build1) ...
# Setting up libpcl-dev (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up libgeoclue-2-0:amd64 (2.4.7-1ubuntu1) ...
# Setting up geoclue-2.0 (2.4.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for systemd (237-3ubuntu10.42) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.2) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# gtk-update-icon-cache: symbol lookup error: gtk-update-icon-cache: undefined symbol: g_log_structured_standard
# WARNING: icon cache generation failed
# Processing triggers for mime-support (3.60ubuntu1) ...

# %%
# !conda config --add channels conda-forge
# !conda install -c sirokujira python-pcl #v0.3
# Out:
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - python-pcl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libgcc-7.2.0               |       h69d50b8_2         304 KB  conda-forge
#     qhull-2015.2               |                0         2.0 MB  sirokujira
#     eigen-3.3.3                |                0         956 KB  conda-forge
#     certifi-2020.11.8          |   py36h5fab9bb_0         150 KB  conda-forge
#     pcl-1.8.1                  |                0        20.9 MB  sirokujira
#     boost-cpp-1.64.0           |                1        17.8 MB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ca-certificates-2020.11.8  |       ha878542_0         145 KB  conda-forge
#     python-pcl-0.3.0           |           py36_0        13.1 MB  sirokujira
#     liblapack-3.8.0            |      17_openblas          11 KB  conda-forge
#     libopenblas-0.3.10         |pthreads_hb3c22a3_4         7.8 MB  conda-forge
#     numpy-1.19.4               |   py36h8732dcd_1         5.2 MB  conda-forge
#     boost-1.64.0               |           py36_4         331 KB  conda-forge
#     vtk-8.0.1                  |                0        76.0 MB  sirokujira
#     libcblas-3.8.0             |      17_openblas          11 KB  conda-forge
#     libblas-3.8.0              |      17_openblas          11 KB  conda-forge
#     flann-1.9.1                |                0        22.9 MB  sirokujira
#     openssl-1.1.1h             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       169.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     boost:           1.64.0-py36_4              conda-forge
#     boost-cpp:       1.64.0-1                   conda-forge
#     eigen:           3.3.3-0                    conda-forge
#     flann:           1.9.1-0                    sirokujira
#     libblas:         3.8.0-17_openblas          conda-forge
#     libcblas:        3.8.0-17_openblas          conda-forge
#     libgcc:          7.2.0-h69d50b8_2           conda-forge
#     liblapack:       3.8.0-17_openblas          conda-forge
#     libopenblas:     0.3.10-pthreads_hb3c22a3_4 conda-forge
#     pcl:             1.8.1-0                    sirokujira
#     python-pcl:      0.3.0-py36_0               sirokujira
#     python_abi:      3.6-1_cp36m                conda-forge
#     qhull:           2015.2-0                   sirokujira
#     vtk:             8.0.1-0                    sirokujira
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.10.14-0                           --> 2020.11.8-ha878542_0     conda-forge
#     certifi:         2020.6.20-pyhd3eb1b0_3                 --> 2020.11.8-py36h5fab9bb_0 conda-forge
#     numpy:           1.14.0-py36h3dfced4_1                  --> 1.19.4-py36h8732dcd_1    conda-forge
#     openssl:         1.1.1h-h7b6447c_0                      --> 1.1.1h-h516909a_0        conda-forge
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# libgcc 7.2.0: 100% 1.0/1 [00:00<00:00,  5.73it/s]
# qhull 2015.2: 100% 1.0/1 [00:01<00:00,  1.21s/it]
# eigen 3.3.3: 100% 1.0/1 [00:01<00:00,  1.14s/it]
# certifi 2020.11.8: 100% 1.0/1 [00:00<00:00, 10.51it/s]
# pcl 1.8.1: 100% 1.0/1 [00:13<00:00, 13.10s/it]
# boost-cpp 1.64.0: 100% 1.0/1 [00:15<00:00, 15.45s/it]
# python_abi 3.6: 100% 1.0/1 [00:00<00:00, 21.42it/s]
# ca-certificates 2020.11.8: 100% 1.0/1 [00:00<00:00, 11.75it/s]
# python-pcl 0.3.0: 100% 1.0/1 [00:07<00:00,  7.74s/it]
# liblapack 3.8.0: 100% 1.0/1 [00:00<00:00, 20.41it/s]
# libopenblas 0.3.10: 100% 1.0/1 [00:02<00:00,  3.20s/it]
# numpy 1.19.4: 100% 1.0/1 [00:02<00:00,  2.74s/it]
# boost 1.64.0: 100% 1.0/1 [00:00<00:00,  3.35it/s]
# vtk 8.0.1: 100% 1.0/1 [00:33<00:00, 33.04s/it]
# libcblas 3.8.0: 100% 1.0/1 [00:00<00:00, 13.90it/s]
# libblas 3.8.0: 100% 1.0/1 [00:00<00:00, 19.31it/s]
# flann 1.9.1: 100% 1.0/1 [00:12<00:00, 108.01s/it]
# openssl 1.1.1h: 100% 1.0/1 [00:00<00:00,  1.03it/s]
# done
# done
# done

# %%
# !sudo apt-get install pcl-tools
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   pcl-tools
# 0 upgraded, 1 newly installed, 0 to remove and 12 not upgraded.
# Need to get 5,693 kB of archives.
# After this operation, 37.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 pcl-tools amd64 1.8.1+dfsg1-2ubuntu2.18.04.1 [5,693 kB]
# Fetched 5,693 kB in 1s (5,869 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package pcl-tools.
# (Reading database ... 157684 files and directories currently installed.)
# Preparing to unpack .../pcl-tools_1.8.1+dfsg1-2ubuntu2.18.04.1_amd64.deb ...
# Unpacking pcl-tools (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Setting up pcl-tools (1.8.1+dfsg1-2ubuntu2.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# # libboost 버전이 일치 하지 않으면 생기는 오류 심벌릭 링크를 적용하여 해결

# %%
# !sudo ln -s /usr/lib/x86_64-linux-gnu/libboost_system.so.1.65.1 /usr/lib/x86_64-linux-gnu/libboost_system.so.1.54.0
# !sudo ln -s /usr/lib/x86_64-linux-gnu/libboost_filesystem.so.1.65.1 /usr/lib/x86_64-linux-gnu/libboost_filesystem.so.1.54.0
# !sudo ln -s /usr/lib/x86_64-linux-gnu/libboost_thread.so.1.65.1 /usr/lib/x86_64-linux-gnu/libboost_thread.so.1.54.0
# !sudo ln -s /usr/lib/x86_64-linux-gnu/libboost_iostreams.so.1.65.1 /usr/lib/x86_64-linux-gnu/libboost_iostreams.so.1.54.0

# %%
# !sudo ln -s /usr/lib/x86_64-linux-gnu/libboost_filesystem.so.1.65.1 /usr/lib/x86_64-linux-gnu/libboost_filesystem.so.1.54.0

# %%
# !sudo ln -s /usr/lib/x86_64-linux-gnu/libboost_thread.so.1.65.1 /usr/lib/x86_64-linux-gnu/libboost_thread.so.1.54.0

# %%
# !sudo ln -s /usr/lib/x86_64-linux-gnu/libboost_iostreams.so.1.65.1 /usr/lib/x86_64-linux-gnu/libboost_iostreams.so.1.54.0

# %% [markdown]
# # ImportError: No module named 'numpy.testing.nosetester' 해결법

# %%
# !conda install -c conda-forge numpy=1.17
# !conda install -c conda-forge scipy==1.1.0
# !conda install -c conda-forge scikit-learn==0.21.3
# Out:
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - numpy=1.17
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     numpy-1.17.5               |   py36h95a1406_0         5.2 MB  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     numpy: 1.19.4-py36h8732dcd_1 conda-forge --> 1.17.5-py36h95a1406_0 conda-forge
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# numpy 1.17.5: 100% 1.0/1 [00:03<00:00,  3.10s/it]
# done
# done
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scipy==1.1.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     scipy-1.1.0                |py36_blas_openblash1522bff_1202        17.4 MB  conda-forge
#     blas-1.1                   |         openblas           1 KB  conda-forge
#     openblas-0.3.3             |    h9ac9557_1001        15.8 MB  conda-forge
#     libopenblas-0.3.10         |       h5a2b251_0         7.8 MB
#     ------------------------------------------------------------
#                                            Total:        41.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     blas:        1.1-openblas               conda-forge
#     openblas:    0.3.3-h9ac9557_1001        conda-forge
#
# The following packages will be UPDATED:
#
#     scipy:       1.0.0-py36hbf646e7_0                   --> 1.1.0-py36_blas_openblash1522bff_1202 conda-forge [blas_openblas]
#
# The following packages will be DOWNGRADED:
#
#     libopenblas: 0.3.10-pthreads_hb3c22a3_4 conda-forge --> 0.3.10-h5a2b251_0
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# scipy 1.1.0: 100% 1.0/1 [00:07<00:00,  7.30s/it]
# blas 1.1: 100% 1.0/1 [00:00<00:00, 27.37it/s]
# openblas 0.3.3: 100% 1.0/1 [00:07<00:00,  7.61s/it]
# libopenblas 0.3.10: 100% 1.0/1 [00:03<00:00,  3.82s/it]
# done
# done
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scikit-learn==0.21.3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     scikit-learn-0.21.3        |   py36hcdab131_0         6.7 MB  conda-forge
#     _openmp_mutex-4.5          |            1_gnu          22 KB  conda-forge
#     joblib-0.17.0              |             py_0         204 KB  conda-forge
#     llvm-openmp-11.0.0         |       hfc4b9b4_1         2.8 MB  conda-forge
#     blas-2.17                  |         openblas          11 KB  conda-forge
#     libgomp-9.3.0              |      h5dbcf3e_17         378 KB  conda-forge
#     libgcc-ng-9.3.0            |      h5dbcf3e_17         7.8 MB  conda-forge
#     scipy-1.1.0                |   py36he2b7bc3_2        17.7 MB
#     liblapacke-3.8.0           |      17_openblas          11 KB  conda-forge
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        35.6 MB
#
# The following NEW packages will be INSTALLED:
#
#     _openmp_mutex: 4.5-1_gnu                             conda-forge
#     joblib:        0.17.0-py_0                           conda-forge
#     libgomp:       9.3.0-h5dbcf3e_17                     conda-forge
#     liblapacke:    3.8.0-17_openblas                     conda-forge
#     llvm-openmp:   11.0.0-hfc4b9b4_1                     conda-forge
#
# The following packages will be UPDATED:
#
#     _libgcc_mutex: 0.1-main                                          --> 0.1-conda_forge       conda-forge
#     blas:          1.1-openblas                          conda-forge --> 2.17-openblas         conda-forge
#     libgcc-ng:     9.1.0-hdf63c60_0                                  --> 9.3.0-h5dbcf3e_17     conda-forge
#     scikit-learn:  0.19.1-py36h7aa7ec6_0                             --> 0.21.3-py36hcdab131_0 conda-forge
#
# The following packages will be DOWNGRADED:
#
#     scipy:         1.1.0-py36_blas_openblash1522bff_1202 conda-forge [blas_openblas] --> 1.1.0-py36he2b7bc3_2
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# scikit-learn 0.21.3: 100% 1.0/1 [00:05<00:00,  5.31s/it]
# _openmp_mutex 4.5: 100% 1.0/1 [00:00<00:00, 16.14it/s]
# joblib 0.17.0: 100% 1.0/1 [00:00<00:00,  4.63it/s]
# llvm-openmp 11.0.0: 100% 1.0/1 [00:01<00:00,  1.07s/it]
# blas 2.17: 100% 1.0/1 [00:00<00:00, 18.63it/s]
# libgomp 9.3.0: 100% 1.0/1 [00:00<00:00,  3.84it/s]
# libgcc-ng 9.3.0: 100% 1.0/1 [00:04<00:00,  4.26s/it]
# scipy 1.1.0: 100% 1.0/1 [00:11<00:00, 11.22s/it]
# liblapacke 3.8.0: 100% 1.0/1 [00:00<00:00, 15.11it/s]
# _libgcc_mutex 0.1: 100% 1.0/1 [00:00<00:00, 16.75it/s]
# done
# done
# done

# %%
import pcl

# %% [markdown]
# # open 3D 설치

# %%
#conda
# !conda install -c open3d-admin open3d

# %% [markdown]
# #ROS 설치(잘 안됨 python 2.7사용 할 경우만 설치)
# http://wiki.ros.org/noetic/Installation/Ubuntu

# %%
# Ubuntu 18용 Melodic 
$ wget https://raw.githubusercontent.com/ROBOTIS-GIT/robotis_tools/master/install_ros_melodic.sh
$ chmod +x install_ros_melodic.sh
$ ./install_ros_melodic.sh

# %%
# create a new environmnet named ros
# !conda install -c conda-forge ros-roslib
python==3.6  # select your desired Python version here (2.7, 3.6, 3.7)
# !conda install -c conda-forge ros-rospy
python==3.6

# %% [markdown]
# #pcl_helper.py (ros가 있어야 작동)
# random_color_gen() : Generates a random set of r,g,b values
# Return: a 3-tuple with r,g,b values (range 0-255)
# ros_to_pcl(sensor_msgs/PointCloud2) : Converts sensor_msgs/PointCloud2 to XYZRGB Point Cloud
# Return: pcl.PointCloud_PointXYZRGB
# pcl_to_ros(pcl.PointCloud_PointXYZRGB): Converts XYZRGB Point Cloud to sensor_msgs/PointCloud2
# Return: sensor_msgs/PointCloud2
# XYZRGB_to_XYZ(XYZRGB_cloud): Converts XYZRGB Point Cloud to XYZ Point CLoud
# Return: pcl.PointCloud
# XYZ_to_XYZRGB(XYZ_cloud, color):Takes a 3-tuple as color and adds it to XYZ Point Cloud
# Return: pcl.PointCloud_PointXYZRGB
# rgb_to_float(color):Converts 3-tuple color to a single float32
# Return: rgb packed as a single float32
# get_color_list(cluster_count) : Creates a list of 3-tuple (rgb) with length of the list = cluster_count
# Return: get_color_list.color_list

# %%
#!/usr/bin/env python

# Copyright (C) 2017 Udacity Inc.
#
# This file is part of Robotic Arm: Pick and Place project for Udacity
# Robotics nano-degree program
#
# All Rights Reserved.

# Author: Harsh Pandya

# Import modules
import rospy
import pcl
import numpy as np
import ctypes
import struct

from std_msgs.msg import Header
from random import randint


def random_color_gen():
    """ Generates a random color
        Args: None
        Returns:
            list: 3 elements, R, G, and B
    """
    r = randint(0, 255)
    g = randint(0, 255)
    b = randint(0, 255)
    return [r, g, b]


def ros_to_pcl(ros_cloud):
    """ Converts a ROS PointCloud2 message to a pcl PointXYZRGB
        Args:
            ros_cloud (PointCloud2): ROS PointCloud2 message
        Returns:
            pcl.PointCloud_PointXYZRGB: PCL XYZRGB point cloud
    """
    points_list = []

    for data in pc2.read_points(ros_cloud, skip_nans=True):
        points_list.append([data[0], data[1], data[2], data[3]])

    pcl_data = pcl.PointCloud_PointXYZRGB()
    pcl_data.from_list(points_list)

    return pcl_data


def pcl_to_ros(pcl_array):
    """ Converts a pcl PointXYZRGB to a ROS PointCloud2 message
        Args:
            pcl_array (PointCloud_PointXYZRGB): A PCL XYZRGB point cloud
        Returns:
            PointCloud2: A ROS point cloud
    """
    ros_msg = PointCloud2()

    ros_msg.header.stamp = rospy.Time.now()
    ros_msg.header.frame_id = "world"

    ros_msg.height = 1
    ros_msg.width = pcl_array.size

    ros_msg.fields.append(PointField(
                            name="x",
                            offset=0,
                            datatype=PointField.FLOAT32, count=1))
    ros_msg.fields.append(PointField(
                            name="y",
                            offset=4,
                            datatype=PointField.FLOAT32, count=1))
    ros_msg.fields.append(PointField(
                            name="z",
                            offset=8,
                            datatype=PointField.FLOAT32, count=1))
    ros_msg.fields.append(PointField(
                            name="rgb",
                            offset=16,
                            datatype=PointField.FLOAT32, count=1))

    ros_msg.is_bigendian = False
    ros_msg.point_step = 32
    ros_msg.row_step = ros_msg.point_step * ros_msg.width * ros_msg.height
    ros_msg.is_dense = False
    buffer = []

    for data in pcl_array:
        s = struct.pack('>f', data[3])
        i = struct.unpack('>l', s)[0]
        pack = ctypes.c_uint32(i).value

        r = (pack & 0x00FF0000) >> 16
        g = (pack & 0x0000FF00) >> 8
        b = (pack & 0x000000FF)

        buffer.append(struct.pack('ffffBBBBIII', data[0], data[1], data[2], 1.0, b, g, r, 0, 0, 0, 0))

    ros_msg.data = "".join(buffer)

    return ros_msg


def XYZRGB_to_XYZ(XYZRGB_cloud):
    """ Converts a PCL XYZRGB point cloud to an XYZ point cloud (removes color info)
        Args:
            XYZRGB_cloud (PointCloud_PointXYZRGB): A PCL XYZRGB point cloud
        Returns:
            PointCloud_PointXYZ: A PCL XYZ point cloud
    """
    XYZ_cloud = pcl.PointCloud()
    points_list = []

    for data in XYZRGB_cloud:
        points_list.append([data[0], data[1], data[2]])

    XYZ_cloud.from_list(points_list)
    return XYZ_cloud


def XYZ_to_XYZRGB(XYZ_cloud, color):
    """ Converts a PCL XYZ point cloud to a PCL XYZRGB point cloud
        All returned points in the XYZRGB cloud will be the color indicated
        by the color parameter.
        Args:
            XYZ_cloud (PointCloud_XYZ): A PCL XYZ point cloud
            color (list): 3-element list of integers [0-255,0-255,0-255]
        Returns:
            PointCloud_PointXYZRGB: A PCL XYZRGB point cloud
    """
    XYZRGB_cloud = pcl.PointCloud_PointXYZRGB()
    points_list = []

    float_rgb = rgb_to_float(color)

    for data in XYZ_cloud:
        points_list.append([data[0], data[1], data[2], float_rgb])

    XYZRGB_cloud.from_list(points_list)
    return XYZRGB_cloud


def rgb_to_float(color):
    """ Converts an RGB list to the packed float format used by PCL
        From the PCL docs:
        "Due to historical reasons (PCL was first developed as a ROS package),
         the RGB information is packed into an integer and casted to a float"
        Args:
            color (list): 3-element list of integers [0-255,0-255,0-255]
        Returns:
            float_rgb: RGB value packed as a float
    """
    hex_r = (0xff & color[0]) << 16
    hex_g = (0xff & color[1]) << 8
    hex_b = (0xff & color[2])

    hex_rgb = hex_r | hex_g | hex_b

    float_rgb = struct.unpack('f', struct.pack('i', hex_rgb))[0]

    return float_rgb


def float_to_rgb(float_rgb):
    """ Converts a packed float RGB format to an RGB list
        Args:
            float_rgb: RGB value packed as a float
        Returns:
            color (list): 3-element list of integers [0-255,0-255,0-255]
    """
    s = struct.pack('>f', float_rgb)
    i = struct.unpack('>l', s)[0]
    pack = ctypes.c_uint32(i).value

    r = (pack & 0x00FF0000) >> 16
    g = (pack & 0x0000FF00) >> 8
    b = (pack & 0x000000FF)

    color = [r,g,b]

    return color


def get_color_list(cluster_count):
    """ Returns a list of randomized colors
        Args:
            cluster_count (int): Number of random colors to generate
        Returns:
            (list): List containing 3-element color lists
    """
    if (cluster_count > len(get_color_list.color_list)):
        for i in xrange(len(get_color_list.color_list), cluster_count):
            get_color_list.color_list.append(random_color_gen())
    return get_color_list.color_list

# %% [markdown]
# #pts to pcd

# %%
filename="DamagedBeam.pts"
from numpy import loadtxt
from numpy import savetxt
lines = loadtxt("/content/sample_data/지면제거data.pts",skiprows=1)
size=str(lines[:,0].size)
header = "VERSION .7\nFIELDS x y z\nSIZE 4 4 4\nTYPE F F F\nCOUNT 1 1 1\nWIDTH "+size+"\nHEIGHT 1\nVIEWPOINT 0 0 0 1 0 0 0\nPOINTS "+size+"\nDATA ascii"
pcd=lines[:,[0,1,2]]
savetxt("/content/sample_data/all.pcd", pcd, fmt="%f",header=header,comments='')

# %% [markdown]
# pts 파일 읽는 코드

# %%
# pts_loader provides a load() method to read data from .pts files of
# point clouds
#
# --------------------------------------------------------
# pts_loader
# Licensed under The MIT License [see LICENSE.md for details]
# Copyright (C) 2017 Samuel Albanie 
# --------------------------------------------------------

def load(path):
    """takes as input the path to a .pts and returns a list of 
	tuples of floats containing the points in in the form:
	[(x_0, y_0, z_0),
	 (x_1, y_1, z_1),
	 ...
	 (x_n, y_n, z_n)]"""
    with open(path) as f:
        rows = [rows.strip() for rows in f]
    
    """Use the curly braces to find the start and end of the point data""" 
    head = rows.index('{') + 1
    tail = rows.index('}')

    """Select the point data split into coordinates"""
    raw_points = rows[head:tail]
    coords_set = [point.split() for point in raw_points]

    """Convert entries from lists of strings to tuples of floats"""
    points = [tuple([float(point) for point in coords]) for coords in coords_set]
    return points

# %% [markdown]
# Euclidean클러스터링

# %%
import pcl
#!/usr/bin/env python

# Copyright (C) 2017 Udacity Inc.
#
# This file is part of Robotic Arm: Pick and Place project for Udacity
# Robotics nano-degree program
#
# All Rights Reserved.

# Author: Harsh Pandya

# Import modules

import pcl
import numpy as np
import ctypes
import struct
from random import randint


def random_color_gen():
    """ Generates a random color
        Args: None
        Returns:
            list: 3 elements, R, G, and B
    """
    r = randint(0, 255)
    g = randint(0, 255)
    b = randint(0, 255)
    return [r, g, b]




def XYZRGB_to_XYZ(XYZRGB_cloud):
    """ Converts a PCL XYZRGB point cloud to an XYZ point cloud (removes color info)
        Args:
            XYZRGB_cloud (PointCloud_PointXYZRGB): A PCL XYZRGB point cloud
        Returns:
            PointCloud_PointXYZ: A PCL XYZ point cloud
    """
    XYZ_cloud = pcl.PointCloud()
    points_list = []

    for data in XYZRGB_cloud:
        points_list.append([data[0], data[1], data[2]])

    XYZ_cloud.from_list(points_list)
    return XYZ_cloud


def XYZ_to_XYZRGB(XYZ_cloud, color):
    """ Converts a PCL XYZ point cloud to a PCL XYZRGB point cloud
        All returned points in the XYZRGB cloud will be the color indicated
        by the color parameter.
        Args:
            XYZ_cloud (PointCloud_XYZ): A PCL XYZ point cloud
            color (list): 3-element list of integers [0-255,0-255,0-255]
        Returns:
            PointCloud_PointXYZRGB: A PCL XYZRGB point cloud
    """
    XYZRGB_cloud = pcl.PointCloud_PointXYZRGB()
    points_list = []

    float_rgb = rgb_to_float(color)

    for data in XYZ_cloud:
        points_list.append([data[0], data[1], data[2], float_rgb])

    XYZRGB_cloud.from_list(points_list)
    return XYZRGB_cloud


def rgb_to_float(color):
    """ Converts an RGB list to the packed float format used by PCL
        From the PCL docs:
        "Due to historical reasons (PCL was first developed as a ROS package),
         the RGB information is packed into an integer and casted to a float"
        Args:
            color (list): 3-element list of integers [0-255,0-255,0-255]
        Returns:
            float_rgb: RGB value packed as a float
    """
    hex_r = (0xff & color[0]) << 16
    hex_g = (0xff & color[1]) << 8
    hex_b = (0xff & color[2])

    hex_rgb = hex_r | hex_g | hex_b

    float_rgb = struct.unpack('f', struct.pack('i', hex_rgb))[0]

    return float_rgb


def float_to_rgb(float_rgb):
    """ Converts a packed float RGB format to an RGB list
        Args:
            float_rgb: RGB value packed as a float
        Returns:
            color (list): 3-element list of integers [0-255,0-255,0-255]
    """
    s = struct.pack('>f', float_rgb)
    i = struct.unpack('>l', s)[0]
    pack = ctypes.c_uint32(i).value

    r = (pack & 0x00FF0000) >> 16
    g = (pack & 0x0000FF00) >> 8
    b = (pack & 0x000000FF)

    color = [r,g,b]

    return color


def get_color_list(cluster_count):
    """ Returns a list of randomized colors
        Args:
            cluster_count (int): Number of random colors to generate
        Returns:
            (list): List containing 3-element color lists
    """
    if (cluster_count > len(get_color_list.color_list)):
        for i in xrange(len(get_color_list.color_list), cluster_count):
            get_color_list.color_list.append(random_color_gen())
    return get_color_list.color_list

def do_euclidean_clustering(white_cloud):
    '''
    :param cloud_objects:
    :return: cluster cloud and cluster indices
    '''
    tree = white_cloud.make_kdtree()

    # Create Cluster-Mask Point Cloud to visualize each cluster separately
    ec = white_cloud.make_EuclideanClusterExtraction()
    ec.set_ClusterTolerance(0.01)
    ec.set_MinClusterSize(20)
    ec.set_MaxClusterSize(40)
    ec.set_SearchMethod(tree)
    cluster_indices = ec.Extract()
    cluster_color = get_color_list(len(cluster_indices))
    color_cluster_point_list = []

    for j, indices in enumerate(cluster_indices):
        for i, indice in enumerate(indices):
            color_cluster_point_list.append([white_cloud[indice][0],
                                             white_cloud[indice][1],
                                             white_cloud[indice][2],
                                             rgb_to_float(cluster_color[j])])

    cluster_cloud = pcl.PointCloud_PointXYZRGB()
    cluster_cloud.from_list(color_cluster_point_list)
    
    return cluster_cloud,cluster_indices

# Euclidean Clustering

get_color_list.color_list = []

white_cloud = pcl.load("/content/TEST3_.pcd")
print(white_cloud)

cluster_cloud,cluster_indices = do_euclidean_clustering(white_cloud)

print(cluster_cloud)
print(cluster_indices)

# %% [markdown]
# k_means 클러스터링

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import pcl


pc = pcl.load("/content/sample_data/result2_.pcd") # "pc.from_file" Deprecated
pc_array = pc.to_array() # pc to Numpy

#cloud = pcl.load_XYZRGBA("tabletop.pcd")
# Read Tree Sample data


data = pd.DataFrame(pc_array)
data.columns=['X','Y','Z']

print('--------------------------data--------------------------')  

print(data)


# we can find appropriate the number of clusters with Inertia
ks = range(20, 40) # range denpend on k's number
inertias = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(data)
    inertias.append(model.inertia_)

print(inertias)

# Plot ks vs inertias
plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

k_num = 0
for i in range(0, len(inertias)):
    if (inertias[i] - inertias[i+1]) <= 1000:
        k_num = (i+1)+20
        break
      
# create model and prediction
#k_num = int(input("input k: "))
model = KMeans(n_clusters=k_num, algorithm='auto')
model.fit(data)
predict = pd.DataFrame(model.predict(data))
predict.columns=['predict']

# concatenate labels to df as a new column
r = pd.concat([data,predict],axis=1)
max = -1
for index in r.predict:
    if max < index:
        max = index

print('--------------------------max, predic 추가한 df--------------------------')
print("Num of K: ", max)
print(r)

# predict 기반 그룹화
groups = r.groupby('predict').size()
print('--------------------------predict기반 점의 개수--------------------------')
print(groups)


# Clustering data visualization
#2D plot
plt.scatter(r['X'], r['Y'], c=r['predict'], s=20, cmap=plt.cm.get_cmap('rainbow', k_num), alpha=0.5)
plt.colorbar(ticks=range(k_num), format='color: %d', label='tree')
# 3d plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d') # Axe3D object


ax.scatter(r['X'], r['Y'], r['Z'], c=r['predict'], cmap=plt.cm.get_cmap('rainbow', k_num), alpha=0.5)

centers = pd.DataFrame(model.cluster_centers_,columns=['X','Y','Z'])
center_x = centers['X']
center_y = centers['Y']
center_z = centers['Z']

# if you want to see 2D centroid plot, delete below '#'
# plt.scatter(center_x,center_y,center_z, marker='D',c='b')

# if you want to see 3D centroid plot
ax.scatter(center_x,center_y,center_z, s=50, marker='D', c='r')
plt.show()

#kdtree 이용 탐색

kdtree = pc.make_kdtree_flann()

searchPoint = pcl.PointCloud()
searchPoints = np.zeros((1,3), dtype=np.float32)

# 정렬
df_sorted_by_values = r.sort_values(by=['predict', 'Z'] ,ascending=False)

# 정렬 결과 출력.
print('--------------------------정렬 결과--------------------------')
print(df_sorted_by_values)

# 정렬한 나무 밑둥 데이터 중에 라벨 별로 가장 큰 값을 가지는 Z 값 추출
print('--------------------------index별 가장 큰 Z값--------------------------')
max_value = df_sorted_by_values.loc[df_sorted_by_values.groupby(['predict'])['Z'].idxmax()]
print(max_value)

searchPoint = pcl.PointCloud()

allPc = pcl.load("/content/sample_data/all.pcd") # "pc.from_file" Deprecated
allPc_array = allPc.to_array() # pc to Numpy
kindex = 0

for mzi in max_value.index.values:
    kcount = 0

    searchPoints = np.zeros((1,3), dtype=np.float32)
    searchPoints[0][0] = max_value.loc[mzi, 'X']
    searchPoints[0][1] = max_value.loc[mzi, 'Y']
    searchPoints[0][2] = max_value.loc[mzi, 'Z']

    searchPoint.from_array(searchPoints) # 초기 z의 최대 값
    
    
    k = 1
    print('--------------------------' +str(kindex)+ '--------------------------')
    print('Neighbors within radius search at (' + str(searchPoint[0][0]) + ' ' + str(
            searchPoint[0][1]) + ' ' + str(searchPoint[0][2]) + ') with k =' + str(k))

    ss = pcl.PointCloud()
    ans = -1000000
    sMax = -1000000

    while(True):
        # radius neighbor search
        print(str(kcount) + '번째 시도')       
        ss2 = np.zeros((1,3), dtype = np.float32)

        if kcount == 0: 
             [ind, sqdist] = kdtree.nearest_k_search_for_cloud(searchPoint, k)
        
        else:
             [ind, sqdist] = kdtree.nearest_k_search_for_cloud(ss, k)

        for i in range(0, ind.size):
             
             # 탐색값중 최고 z값 찾아서 searchPoints 배열 만들어서 넣어주고 searchPoint(pcd)에 다시 넣어주기 
            if sMax < allPc_array[ind[0][i]][2]:

                ss2[0][0] = allPc_array[ind[0][i]][0]   
                ss2[0][1] = allPc_array[ind[0][i]][1]  
                ss2[0][2] = allPc_array[ind[0][i]][2]
                sMax = ss2[0][2]
                ss.from_array(ss2)

            print('(' + str(allPc_array[ind[0][i]][0]) + ' ' + str(allPc_array[ind[0][i]][1]) + ' ' + str( allPc_array[ind[0][i]][2]) + ' (squared distance: ' + str(sqdist[0][i]) + ')')
        
        print(str(kcount) + '번째 시도에서 최대 z값을 가진 좌표: ' + '(' + str(ss2[0][0]) + ' ' + str(ss2[0][1]) + ' ' + str(ss2[0][2])+')')
        print('------------------------')
        kcount+=1    
        if ans == sMax: break
        else: ans = sMax

    print('*******'+ str(kindex) + '번째 나무의 최대 높이 ' + str(ans))
    kindex+=1
# Out:
# --------------------------data--------------------------
#              X        Y        Z
# 0      5.73202 -0.74213  2.00003
# 1     -5.85224 -3.51000  2.00003
# 2     -1.55024 -6.14023  2.00004
# 3     -0.15085 -2.35509  2.00004
# 4      5.57676  5.75816  2.00004
# ...        ...      ...      ...
# 46770 -6.55157  0.85491  2.49994
# 46771 -0.05673 -2.31840  2.49994
# 46772  1.28519  4.79566  2.49997
# 46773  1.36988  2.13100  2.49999
# 46774  1.40314  2.09217  2.50002
#
# [46775 rows x 3 columns]
# [8918.818638159231, 6546.632383378622, 4855.196090907267, 3002.0173563139797, 2239.235594644138, 1748.144720312152, 1626.6155224260751, 1460.955918995214, 1391.2903351288062, 1301.3891569791792, 1246.21115464513, 1164.3707165888493, 1115.920238694314, 1093.5163534876615, 1043.6622315020747, 996.3967199567164, 934.3893917206133, 924.1813403519259, 884.4158394602977, 844.7314126737379]
# --------------------------max, predic 추가한 df--------------------------
# Num of K:  23
#              X        Y        Z  predict
# 0      5.73202 -0.74213  2.00003        3
# 1     -5.85224 -3.51000  2.00003       21
# 2     -1.55024 -6.14023  2.00004        1
# 3     -0.15085 -2.35509  2.00004        5
# 4      5.57676  5.75816  2.00004        0
# ...        ...      ...      ...      ...
# 46770 -6.55157  0.85491  2.49994        2
# 46771 -0.05673 -2.31840  2.49994        5
# 46772  1.28519  4.79566  2.49997        9
# 46773  1.36988  2.13100  2.49999        4
# 46774  1.40314  2.09217  2.50002        4
#
# [46775 rows x 4 columns]
# --------------------------predict기반 점의 개수--------------------------
# predict
# 0     1585
# 1     3014
# 2     2159
# 3     2748
# 4     6585
# 5     7707
# 6     2614
# 7     2998
# 8      346
# 9     3644
# 10    1439
# 11     660
# 12    1163
# 13     446
# 14     831
# 15     659
# 16    2094
# 17    1587
# 18    1144
# 19     794
# 20     739
# 21    1037
# 22     497
# 23     285
# dtype: int64
# --------------------------정렬 결과--------------------------
#              X        Y        Z  predict
# 46764  3.15844  7.07280  2.49989       23
# 46638  3.25240  7.02949  2.49837       23
# 46608  3.16876  7.06997  2.49803       23
# 45981  3.15859  7.07331  2.49085       23
# 45731  3.17004  7.06954  2.48807       23
# ...        ...      ...      ...      ...
# 130    5.52517  5.86188  2.00136        0
# 79     5.52424  5.87092  2.00075        0
# 30     5.73904  5.71625  2.00030        0
# 28     5.59084  5.74823  2.00027        0
# 4      5.57676  5.75816  2.00004        0
#
# [46775 rows x 4 columns]
# --------------------------index별 가장 큰 Z값--------------------------
#              X         Y        Z  predict
# 46759  5.74751   5.72729  2.49986        0
# 46730 -1.78271  -6.01472  2.49945        1
# 46770 -6.55157   0.85491  2.49994        2
# 46755  5.77071  -0.65376  2.49981        3
# 46774  1.40314   2.09217  2.50002        4
# 46771 -0.05673  -2.31840  2.49994        5
# 46752  4.12129  -5.15083  2.49975        6
# 46717 -3.51781   3.90868  2.49930        7
# 46629 -7.26214  -4.52473  2.49827        8
# 46772  1.28519   4.79566  2.49997        9
# 46726  8.71270   1.42579  2.49939       10
# 46738 -8.04669   5.78005  2.49953       11
# 46747  2.89836  -9.05188  2.49962       12
# 46668 -2.30789  11.00880  2.49875       13
# 46648  8.33374  -4.96913  2.49844       14
# 46757 -7.24218  -8.04231  2.49982       15
# 46722 -7.00216   3.53599  2.49934       16
# 46707 -3.00663  -7.58303  2.49916       17
# 46737  8.29226  -1.67521  2.49952       18
# 46740 -8.44997   0.11106  2.49956       19
# 46763 -8.60528  -2.89288  2.49988       20
# 46751 -5.87202  -3.53922  2.49973       21
# 46667 -9.90369   4.10504  2.49873       22
# 46764  3.15844   7.07280  2.49989       23
# --------------------------0--------------------------
# Neighbors within radius search at (5.747509956359863 5.727290153503418 2.4998600482940674) with k =1
# 0번째 시도
# (-0.31656 -0.53022 10.20532 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.31656 -0.53022 10.20532)
# ------------------------
# 1번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 62.60895)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******0번째 나무의 최대 높이 11.51032
# --------------------------1--------------------------
# Neighbors within radius search at (-1.7827099561691284 -6.0147199630737305 2.4994499683380127) with k =1
# 0번째 시도
# (0.50144 -0.10622 11.07432 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (0.50144 -0.10622 11.07432)
# ------------------------
# 1번째 시도
# (-0.42456 -2.11422 10.01032 (squared distance: 78.72528)
# 1번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******1번째 나무의 최대 높이 11.07432
# --------------------------2--------------------------
# Neighbors within radius search at (-6.551569938659668 0.8549100160598755 2.4999399185180664) with k =1
# 0번째 시도
# (-0.47256 -0.95422 9.61432 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.47256 -0.95422 9.61432)
# ------------------------
# 1번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 52.602455)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******2번째 나무의 최대 높이 11.51032
# --------------------------3--------------------------
# Neighbors within radius search at (5.770709991455078 -0.6537600159645081 2.499809980392456) with k =1
# 0번째 시도
# (1.13644 -1.11122 9.85532 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (1.13644 -1.11122 9.85532)
# ------------------------
# 1번째 시도
# (-0.99556 -1.58522 10.33932 (squared distance: 56.937237)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.99556 -1.58522 10.33932)
# ------------------------
# 2번째 시도
# (0.99944 -1.81422 10.07932 (squared distance: 62.746796)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******3번째 나무의 최대 높이 10.33932
# --------------------------4--------------------------
# Neighbors within radius search at (1.4031399488449097 2.092170000076294 2.5000200271606445) with k =1
# 0번째 시도
# (0.24444 -0.80222 10.85832 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (0.24444 -0.80222 10.85832)
# ------------------------
# 1번째 시도
# (-0.42456 -2.11422 10.01032 (squared distance: 72.25202)
# 1번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******4번째 나무의 최대 높이 10.85832
# --------------------------5--------------------------
# Neighbors within radius search at (-0.0567299984395504 -2.3183999061584473 2.4999399185180664) with k =1
# 0번째 시도
# (-0.42456 -2.11422 10.01032 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.42456 -2.11422 10.01032)
# ------------------------
# 1번째 시도
# (-0.04356 -0.55322 11.01832 (squared distance: 56.539112)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.04356 -0.55322 11.01832)
# ------------------------
# 2번째 시도
# (-0.97656 -0.73622 11.37132 (squared distance: 75.66637)
# 2번째 시도에서 최대 z값을 가진 좌표: (-0.97656 -0.73622 11.37132)
# ------------------------
# 3번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 81.94705)
# 3번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 4번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 4번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******5번째 나무의 최대 높이 11.51032
# --------------------------6--------------------------
# Neighbors within radius search at (4.12129020690918 -5.150829792022705 2.4997498989105225) with k =1
# 0번째 시도
# (-0.06356 -2.03822 11.15732 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.06356 -2.03822 11.15732)
# ------------------------
# 1번째 시도
# (-0.42456 -2.11422 10.01032 (squared distance: 75.02878)
# 1번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******6번째 나무의 최대 높이 11.15732
# --------------------------7--------------------------
# Neighbors within radius search at (-3.517810106277466 3.908679962158203 2.499300003051758) with k =1
# 0번째 시도
# (-0.83056 -1.46922 9.87132 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.83056 -1.46922 9.87132)
# ------------------------
# 1번째 시도
# (-0.74456 -0.24322 9.56832 (squared distance: 55.567886)
# 1번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******7번째 나무의 최대 높이 9.87132
# --------------------------8--------------------------
# Neighbors within radius search at (-7.262139797210693 -4.524730205535889 2.498270034790039) with k =1
# 0번째 시도
# (-0.70756 -0.14222 10.81532 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.70756 -0.14222 10.81532)
# ------------------------
# 1번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 74.22994)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******8번째 나무의 최대 높이 11.51032
# --------------------------9--------------------------
# Neighbors within radius search at (1.2851899862289429 4.795660018920898 2.499969959259033) with k =1
# 0번째 시도
# (-0.31156 -0.99822 10.85032 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.31156 -0.99822 10.85032)
# ------------------------
# 1번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 71.509964)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******9번째 나무의 최대 높이 11.51032
# --------------------------10--------------------------
# Neighbors within radius search at (8.712699890136719 1.4257899522781372 2.499389886856079) with k =1
# 0번째 시도
# (-0.12556 -1.00522 9.75132 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.12556 -1.00522 9.75132)
# ------------------------
# 1번째 시도
# (-0.97656 -0.73622 11.37132 (squared distance: 54.298664)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.97656 -0.73622 11.37132)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 81.94705)
# 2번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 3번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 3번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******10번째 나무의 최대 높이 11.51032
# --------------------------11--------------------------
# Neighbors within radius search at (-8.046689987182617 5.780049800872803 2.499530076980591) with k =1
# 0번째 시도
# (-0.57856 -0.31922 10.99332 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.57856 -0.31922 10.99332)
# ------------------------
# 1번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 76.34706)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******11번째 나무의 최대 높이 11.51032
# --------------------------12--------------------------
# Neighbors within radius search at (2.898360013961792 -9.0518798828125 2.499619960784912) with k =1
# 0번째 시도
# (-0.11356 -0.72922 10.85632 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.11356 -0.72922 10.85632)
# ------------------------
# 1번째 시도
# (-0.97656 -0.73622 11.37132 (squared distance: 72.343185)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.97656 -0.73622 11.37132)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 81.94705)
# 2번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 3번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 3번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******12번째 나무의 최대 높이 11.51032
# --------------------------13--------------------------
# Neighbors within radius search at (-2.307889938354492 11.00879955291748 2.4987499713897705) with k =1
# 0번째 시도
# (-1.02156 -0.57322 9.82332 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-1.02156 -0.57322 9.82332)
# ------------------------
# 1번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 57.498405)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******13번째 나무의 최대 높이 11.51032
# --------------------------14--------------------------
# Neighbors within radius search at (8.333740234375 -4.969130039215088 2.4984400272369385) with k =1
# 0번째 시도
# (0.22444 -1.97922 10.07332 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (0.22444 -1.97922 10.07332)
# ------------------------
# 1번째 시도
# (-1.03856 -0.83022 10.30032 (squared distance: 57.544636)
# 1번째 시도에서 최대 z값을 가진 좌표: (-1.03856 -0.83022 10.30032)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 63.913616)
# 2번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 3번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 3번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******14번째 나무의 최대 높이 11.51032
# --------------------------15--------------------------
# Neighbors within radius search at (-7.242179870605469 -8.042309761047363 2.4998199939727783) with k =1
# 0번째 시도
# (1.02344 -1.34422 10.02132 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (1.02344 -1.34422 10.02132)
# ------------------------
# 1번째 시도
# (-0.99556 -1.58522 10.33932 (squared distance: 58.64098)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.99556 -1.58522 10.33932)
# ------------------------
# 2번째 시도
# (0.99944 -1.81422 10.07932 (squared distance: 62.746796)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******15번째 나무의 최대 높이 10.33932
# --------------------------16--------------------------
# Neighbors within radius search at (-7.00216007232666 3.535989999771118 2.499340057373047) with k =1
# 0번째 시도
# (0.84444 -1.47922 11.28632 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (0.84444 -1.47922 11.28632)
# ------------------------
# 1번째 시도
# (-0.99556 -1.58522 10.33932 (squared distance: 78.682076)
# 1번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******16번째 나무의 최대 높이 11.28632
# --------------------------17--------------------------
# Neighbors within radius search at (-3.0066299438476562 -7.5830302238464355 2.499160051345825) with k =1
# 0번째 시도
# (-0.83056 -2.19022 10.09432 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.83056 -2.19022 10.09432)
# ------------------------
# 1번째 시도
# (-0.49556 -0.86022 10.46232 (squared distance: 58.15191)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.49556 -0.86022 10.46232)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 65.66993)
# 2번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 3번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 3번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******17번째 나무의 최대 높이 11.51032
# --------------------------18--------------------------
# Neighbors within radius search at (8.29226016998291 -1.6752099990844727 2.4995200634002686) with k =1
# 0번째 시도
# (-1.01956 -0.71522 10.06932 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-1.01956 -0.71522 10.06932)
# ------------------------
# 1번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 60.683475)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******18번째 나무의 최대 높이 11.51032
# --------------------------19--------------------------
# Neighbors within radius search at (-8.449970245361328 0.1110600009560585 2.4995601177215576) with k =1
# 0번째 시도
# (0.85144 -1.30522 9.86032 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (0.85144 -1.30522 9.86032)
# ------------------------
# 1번째 시도
# (-0.99556 -1.58522 10.33932 (squared distance: 55.998653)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.99556 -1.58522 10.33932)
# ------------------------
# 2번째 시도
# (0.99944 -1.81422 10.07932 (squared distance: 62.746796)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******19번째 나무의 최대 높이 10.33932
# --------------------------20--------------------------
# Neighbors within radius search at (-8.605279922485352 -2.8928799629211426 2.499880075454712) with k =1
# 0번째 시도
# (-0.46256 -0.50422 9.79732 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.46256 -0.50422 9.79732)
# ------------------------
# 1번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 56.661644)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 2번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******20번째 나무의 최대 높이 11.51032
# --------------------------21--------------------------
# Neighbors within radius search at (-5.8720197677612305 -3.539220094680786 2.499730110168457) with k =1
# 0번째 시도
# (0.39744 -0.54322 11.38132 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (0.39744 -0.54322 11.38132)
# ------------------------
# 1번째 시도
# (-0.42456 -2.11422 10.01032 (squared distance: 82.23645)
# 1번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******21번째 나무의 최대 높이 11.38132
# --------------------------22--------------------------
# Neighbors within radius search at (-9.903690338134766 4.105040073394775 2.498729944229126) with k =1
# 0번째 시도
# (-0.10956 -2.02522 11.16032 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.10956 -2.02522 11.16032)
# ------------------------
# 1번째 시도
# (-0.97656 -0.73622 11.37132 (squared distance: 75.08912)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.97656 -0.73622 11.37132)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 81.94705)
# 2번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 3번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 3번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******22번째 나무의 최대 높이 11.51032
# --------------------------23--------------------------
# Neighbors within radius search at (3.158440113067627 7.072800159454346 2.499890089035034) with k =1
# 0번째 시도
# (-0.00956 -0.99922 9.76232 (squared distance: 0.0)
# 0번째 시도에서 최대 z값을 가진 좌표: (-0.00956 -0.99922 9.76232)
# ------------------------
# 1번째 시도
# (-0.97656 -0.73622 11.37132 (squared distance: 54.477848)
# 1번째 시도에서 최대 z값을 가진 좌표: (-0.97656 -0.73622 11.37132)
# ------------------------
# 2번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 81.94705)
# 2번째 시도에서 최대 z값을 가진 좌표: (-0.77356 -1.02522 11.51032)
# ------------------------
# 3번째 시도
# (-0.77356 -1.02522 11.51032 (squared distance: 83.2937)
# 3번째 시도에서 최대 z값을 가진 좌표: (0.0 0.0 0.0)
# ------------------------
# *******23번째 나무의 최대 높이 11.51032

# %% [markdown]
# DBscan 클러스터링

# %%
import pandas as pd
from sklearn.cluster import DBSCAN
import matplotlib.pyplot  as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import pcl

pc = pcl.load("/content/sample_data/result2_.pcd") # "pc.from_file" Deprecated
pc_array = pc.to_array() # pc to Numpy
#cloud = pcl.load_XYZRGBA("tabletop.pcd")
# Read Tree Sample data

data = pd.DataFrame(pc_array)
data.columns=['X','Y','Z']

print(data)


# create model and prediction
model = DBSCAN(min_samples=6)
predict = pd.DataFrame(model.fit_predict(data))
predict.columns=['predict']

# concatenate labels to df as a new column
r = pd.concat([data,predict],axis=1)
print(r)


# scatter plot
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
ax.scatter(r['X'], r['Y'], r['Z'], c=r['predict'], alpha=0.5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# # octree search 알고리즘

# %%
import pcl
import numpy as np
import random

cloud = pcl.load("/content/sample_data/result2_.pcd")
resolution = 0.2
octree = cloud.make_octreeSearch(resolution)
octree.add_points_from_input_cloud()


searchPoint = pcl.PointCloud()
searchPoints = np.zeros((1, 3), dtype=np.float32)
searchPoints[0][0] = cloud[3000][0]
searchPoints[0][1] = cloud[3000][1]
searchPoints[0][2] = cloud[3000][2]
#searchPoints = (cloud[3000][0], cloud[3000][1], cloud[3000][2])

searchPoint.from_array(searchPoints)


ind = octree.VoxelSearch(searchPoint)

print('Neighbors within voxel search at (' + str(searchPoint[0][0]) + ' ' + str(
    searchPoint[0][1]) + ' ' + str(searchPoint[0][2]) + ')')

for i in range(0, 5):#range(0, ind.size):
    print('index = ' + str(ind[i]))
    print('(' + str(cloud[ind[i]][0]) + ' ' +
          str(cloud[ind[i]][1]) + ' ' + str(cloud[ind[i]][2]) + ')')
    
#K nearest neighbor search
K = 10
print('K nearest neighbor search at (' + str(searchPoint[0][0]) + ' ' + str(
        searchPoint[0][1]) + ' ' + str(searchPoint[0][2]) + ') with K=' + str(K))    


[ind, sqdist] = octree.nearest_k_search_for_cloud(searchPoint, K)
for i in range(0, ind.size):
    print('(' + str(cloud[ind[0][i]][0]) + ' ' + str(cloud[ind[0][i]][1]) + ' ' + str(
        cloud[ind[0][i]][2]) + ' (squared distance: ' + str(sqdist[0][i]) + ')')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-75c1adb0c78b> in <module>()
# ----> 1 import pcl
#       2 import numpy as np
#       3 import random
#       4
#       5 cloud = pcl.load("/content/sample_data/result2_.pcd")
#
# ModuleNotFoundError: No module named 'pcl'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# #KdTree 알고리즘

# %%
import pcl
import numpy as np
import random
cloud = pcl.load("/content/sample_data/result2_.pcd")
kdtree = cloud.make_kdtree_flann()

searchPoint = pcl.PointCloud()
searchPoints = np.zeros((1,3), dtype=np.float32)
searchPoints[0][0] = cloud[3000][0]
searchPoints[0][1] = cloud[3000][1]
searchPoints[0][2] = cloud[3000][2]

searchPoint.from_array(searchPoints)

# K nearest neighbor search
K = 10
print('K nearest neighbor search at (' + str(searchPoint[0][0]) + ' ' + str(
        searchPoint[0][1]) + ' ' + str(searchPoint[0][2]) + ') with K=' + str(K))

[ind, sqdist] = kdtree.nearest_k_search_for_cloud(searchPoint, K)
for i in range(0, ind.size):
    print('(' + str(cloud[ind[0][i]][0]) + ' ' + str(cloud[ind[0][i]][1]) + ' ' + str(
        cloud[ind[0][i]][2]) + ' (squared distance: ' + str(sqdist[0][i]) + ')')

# Neighbors within radius search
radius = 0.02
print('Neighbors within radius search at (' + str(searchPoint[0][0]) + ' ' + str(
        searchPoint[0][1]) + ' ' + str(searchPoint[0][2]) + ') with radius=' + str(radius))

[ind, sqdist] = kdtree.radius_search_for_cloud(searchPoint, radius)
for i in range(0, ind.size):
    print('(' + str(cloud[ind[0][i]][0]) + ' ' + str(cloud[ind[0][i]][1]) + ' ' + str(
        cloud[ind[0][i]][2]) + ' (squared distance: ' + str(sqdist[0][i]) + ')')
# Out:
# K nearest neighbor search at (5.737170219421387 -0.6957399845123291 2.0306100845336914) with K=10
# (5.737170219421387 -0.6957399845123291 2.0306100845336914 (squared distance: 0.0)
# (5.737269878387451 -0.6961299777030945 2.0376698970794678 (squared distance: 5.0002982e-05)
# (5.742080211639404 -0.6897500157356262 2.0315799713134766 (squared distance: 6.092843e-05)
# (5.739180088043213 -0.6952800154685974 2.0228099822998047 (squared distance: 6.509274e-05)
# (5.73661994934082 -0.7035499811172485 2.027060031890869 (squared distance: 7.390172e-05)
# (5.7365899085998535 -0.704010009765625 2.0351099967956543 (squared distance: 8.897929e-05)
# (5.73921012878418 -0.6901400089263916 2.038259983062744 (squared distance: 9.4041905e-05)
# (5.743969917297363 -0.6893500089645386 2.024780035018921 (squared distance: 0.00012105715)
# (5.736509799957275 -0.7031599879264832 2.0199999809265137 (squared distance: 0.00016806691)
# (5.733839988708496 -0.7043499946594238 2.040800094604492 (squared distance: 0.000189059)
# Neighbors within radius search at (5.737170219421387 -0.6957399845123291 2.0306100845336914) with radius=0.02

# %% [markdown]
# # colab런타임 해제 방지 (f12눌러서 콘솔에 복사 붙여넣기)

# %%
function ClickConnect(){
console.log("Working"); 
document
  .querySelector('#top-toolbar > colab-connect-button')
  .shadowRoot.querySelector('#connect')
  .click() 
}
setInterval(ClickConnect,60000)
